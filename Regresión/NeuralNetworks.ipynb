# %% [markdown]
# ___
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://bernardmarr.com/img/What%20is%20an%20Artificial%20Neural%20Networks.jpg" width="350px" height="180px" />
# ```Cristopher Corona Velasco```
#
# ```743940```
#
#
# # <font color= #8A0829> Laboratorio de Modelado de Datos </font>
# #### <font color= #2E9AFE> `Martes y Viernes (Videoconferencia) de 13:00 - 15:00 hrs`</font>
# - <Strong> Sara Eugenia Rodríguez </Strong>
# - <Strong> Año </Strong>: 2025
# - <Strong> Email: </Strong>  <font color="blue"> `cd682324@iteso.mx` </font>
# ___
#
# <p style="text-align:right;"> Imagen recuperada de: https://bernardmarr.com/img/What%20is%20an%20Artificial%20Neural%20Networks.jpg</p>
#
# ### <font color= #2E9AFE> Tema: Redes Neuronales</font>

# %% [markdown]
# Las redes neuronales profundas (deep learning) han ganado mucha popularidad en los últimos años, especialmente para problemas complejos, como el reconocimiento de imágenes, el procesamiento del lenguaje natural y otras aplicaciones que requieren modelos potentes.
#
# Sin embargo, las redes neuronales básicas también pueden usarse en problemas de aprendizaje supervisado más simples, como regresión o clasificación, AUNQUE hay varias razones por las cuales otros algoritmos son más comunes en estos casos...
#
# 1. Complejidad computacional
# 2. Sobreajuste (Overfitting)
# 3. Necesidad de más datos
# 4. Tuning de Hiperparámetros (las redes neuronales tienen muchos hiperparámetros)
# 5. Interpretabilidad, son modelos de caja negra
#
# **¿Cuándo se utilizan redes neuronales en aprendizaje supervisado?**
#
# Aunque no siempre son la primera opción para problemas simples, las redes neuronales pueden ser muy útiles en problemas supervisados más complejos donde:
#
# - Hay gran cantidad de datos disponibles
# - Los problemas son no lineales
# - Hay tareas de percepción involucradas (como visión por computadora, reconocimiento de voz o procesamiento de lenguaje natural), donde las redes neuronales profundas sobresalen.

# %% [markdown]
# Dentro de la caja negra...
#
# **¿Qué es una neurona?**
#
# Es un nombre elegante que le pusieron para referirse a una función en los años de 1940-1950. Se creeía que los nodos eran como neuronas del cerebro.
#
# **¿Qué es una función?**
#
# Es un nombre elegante que pusieron para referirse a algo que toma cosas de entrada, aplica alguna lógica y saca un resultado.
#
# **¿Qué es una red neuronal?**
#
# Es la interconexión de múltiples neuronas (funciones) para resolver un problema complejo que una sola neurona no podría. Dentro de los componentes existen *nodos* y *conexiones*
#
# **Pasos que hace la red neuronal:**
#
# 1. Combinación de las variables de entrada (X). Cada señal recibida tiene una constante w (peso/weight) que permite manipular la importancia de cada variable de entrada.
# 2. Neurona de respuesta. Considerando todas las variables de entrada, la neurona genera una señal de respuesta a través de una función.
#
# **Tipos de capas en la red neuronal**
#
# - Capa de entrada: capa que toma los datos de entrada
# - Capas ocultas: toman las entradas de otra capa y pasan a salida hacia otra capa (son intermediarias entre la entrada y la salida)
# - Capas de salida: capa que hace la predicción
#
# <img style="float: center; margin: 0px 0px 0px 0px;" src="https://www.smartsheet.com/sites/default/files/IC-simplified-artificial-neural-networks-corrected.svg" width="350px" height="180px" />

# %% [markdown]
# **Funciones de activación**
#
# El comportamiento de las neuronas de las redes neuronales es basado en la función en la que la neurona se especializó. Una neurona puede cambiar su respuesta dependiendo de la función de activación $\varphi(*)$ que sea seleccionada
#
# Funciones comunes:
# 1. Lineal: $\varphi(\nu)=\nu$
# 2. Sigmoidal: $\varphi(\nu)=\frac{e^{\nu}}{1+e^{\nu}}$
# 3. Tanh: $\varphi(\nu)=\frac{e^{\nu}-e^{-\nu}}{e^{\nu}+e^{-\nu}}=tanh(\nu)$
# 4. Softplus: $\varphi(\nu)=log(1+e^{\nu})$
# 5. RELU: $\varphi(\nu)=max(0,\nu)$
#
# Las funciones de activación suelen ser diferenciables, lo que significa que la derivada de primer orden se puede calcular para un valor de entrada dado. Esto es necesario dado que las redes neuronales generalmente se entrenan utilizando el algoritmo de backpropagation que requiere la derivada del error de predicción para actualizar los pesos del modelo.
#
# **¿Cómo elegir la función de activación para las capas ocultas?**
#
# - RELU: es la más utilizada para capas ocultas. Es fácil de calcular, lo que la hace más rápida para entrenar. Es simple de implementar y no es tan susceptible a gradientes que se desvanecen
# - Leaky RELU: Similar a ReLU, pero permite valores negativos pequeños cuando x≤0, lo que evita que las neuronas queden completamente inactivas.
# - Evita Sigmoid y Tanh en las capas ocultas
#
# **¿Cómo elegir la función de activación para las capas de salida?**
#
# - Lineal: Para problemas de regresión donde la salida es un valor continuo.
# - Sigmoidal: típicamente para problemas de clasificación binaria.
# - Softmax: Para problemas de clasificación multiclase
#
#
# **¿Cómo son las redes neuronales para regresión?**
#
# $$\nu^{1} = w_{0}^{1}+w^{1}$$
# $$y^{1} = \varphi(\nu^{1})$$
# $$\nu^{2} = w_{0}^{2}+w^{2}y_{1}$$
# <font color= #2E9AFE>$$y^{2} = \varphi(\nu^{2})$$</font>
#
# La única diferencia es la última salida. La función de la salida tiene que ser **lineal**
#
#
# **¿Cómo elegir cuántas capas ocultas?**
#
# - Problemas sencillos: Una sola capa oculta suele ser suficiente para capturar patrones simples.
# - Problemas más complejos (con relaciones no lineales más complicadas): Dos capas ocultas pueden ser útiles
#
# En la práctica, la mayoría de los problemas sencillos no necesitan más de 1 o 2 capas ocultas.
#
# **¿Cómo elegir cuántas neuronas en las capas ocultas?**
#
# - Un buen punto de partida es comenzar con un número de neuronas que sea similar o cercano al número de características de entrada.
# - Para problemas simples, puedes comenzar con entre 4 y 16 neuronas por capa.
# - Si los datos tienen una cantidad moderada de complejidad o son no lineales, podrías aumentar a 32 o 64 neuronas en la capa oculta.
# - Evita tener muchas más neuronas que características de entrada, ya que eso puede llevar a un sobreajuste.
# - En redes con múltiples capas ocultas, una estrategia común es que las capas posteriores tengan menos neuronas que las capas iniciales. Esto es porque las primeras capas extraen más características, mientras que las capas más profundas se enfocan en combinarlas.
#
# **Recomendaciones**
#
# - Se recomienda hacer un pre-procesamiento de los datos - Escalamiento
# - Comúnmente todas las capas ocultas usan la misma función de activación
# - La función de salida generalmente usa diferente función de activación que el de las capas ocultas.
# - En la experiencia, conviene más aumentar el número de neuronas ocultas en lugar de aumentar el número de capas ocultas.
# - Se recomienda no usar muchas capas ocultas
#
#
# **¿Por qué el deep learning no funciona tan bien en problemas clásicos de regresión/clasificación?**
#
# Gran parte del éxito de las redes neuronales modernas proviene de su capacidad para explotar la naturaleza compositiva del mundo. Es decir, en problemas de percepción como el análisis de imágenes o audio, las características tienen un orden (espacial o temporal) y los patrones locales se agregan para formar conceptos y objetos de nivel superior (por ejemplo, la imagen de un automóvil está hecha de ruedas y otras partes, que están hechas de características visuales de nivel inferior, que están hechas de formas básicas como bordes, círculos y líneas, etc.).
#
# Las redes neuronales modernas, como las redes neuronales convolucionales (CNN), aprovechan esto aprendiendo características cada vez más abstractas en las capas más profundas.
#
# Por el contrario, los problemas de regresión clásicos constan de una serie de características no ordenadas, y el valor objetivo se puede predecir bastante bien con un modelo lineal/no lineal superficial de las características de entrada. En cierto sentido, esta propiedad composicional presente en problemas como la clasificación de imágenes o el reconocimiento de voz no está presente en problemas como "Predecir los ingresos de un individuo en función de su sexo, edad, nacionalidad, grado académico, tamaño de la familia...".

# %% [markdown]
# ## Ejemplo: Eficiencia de Energia
#
# Se busca analizar la eficiencia energética de los edificios.
#
# Se realizaron análisis energéticos utilizando 12 tipos de edificios diferentes simulados en Ecotect.
#
# Los edificios se diferencian en cuanto a la superficie con cristales, la distribución del área acristalada y la orientación, entre otros parámetros.
#
# Se simularon varios escenarios en función de las características antes mencionadas para obtener 768 formas de edificios.
#
# El conjunto de datos comprende 768 muestras y 8 características, con el objetivo de predecir dos respuestas con valor real.
#
# Información de atributos:
# - X1 Relative Compactness
# - X2 Surface Area
# - X3 Wall Area
# - X4 Roof Area
# - X5 Overall Height
# - X6 Orientation
# - X7 Glazing Area
# - X8 Glazing Area Distribution
#
# Targets:
# - Y1: Heating Load (in Wh)
# - Y2: Cooling Load (in Wh)
# -
# Las características son numéricas y representan diversas características físicas del edificio, mientras que las variables objetivo representan la energía necesaria para calefacción y enfriamiento.

# %%
##pip install tensorflow

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("ENB2012_data.csv")

df.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      768 non-null    float64
#  1   X2      768 non-null    float64
#  2   X3      768 non-null    float64
#  3   X4      768 non-null    float64
#  4   X5      768 non-null    float64
#  5   X6      768 non-null    int64
#  6   X7      768 non-null    float64
#  7   X8      768 non-null    int64
#  8   Y1      768 non-null    float64
#  9   Y2      768 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 60.1 KB

# %%
df.describe()
# Out:
#                X1          X2          X3          X4         X5          X6  \
# count  768.000000  768.000000  768.000000  768.000000  768.00000  768.000000
# mean     0.764167  671.708333  318.500000  176.604167    5.25000    3.500000
# std      0.105777   88.086116   43.626481   45.165950    1.75114    1.118763
# min      0.620000  514.500000  245.000000  110.250000    3.50000    2.000000
# 25%      0.682500  606.375000  294.000000  140.875000    3.50000    2.750000
# 50%      0.750000  673.750000  318.500000  183.750000    5.25000    3.500000
# 75%      0.830000  741.125000  343.000000  220.500000    7.00000    4.250000
# max      0.980000  808.500000  416.500000  220.500000    7.00000    5.000000
#
#                X7         X8          Y1          Y2
# count  768.000000  768.00000  768.000000  768.000000
# mean     0.234375    2.81250   22.307201   24.587760
# std      0.133221    1.55096   10.090196    9.513306
# min      0.000000    0.00000    6.010000   10.900000
# 25%      0.100000    1.75000   12.992500   15.620000
# 50%      0.250000    3.00000   18.950000   22.080000
# 75%      0.400000    4.00000   31.667500   33.132500
# max      0.400000    5.00000   43.100000   48.030000

# %%
#Matriz de correlaciones
correlation_matrix = df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
#Correlaciones con el target
correlation_target = df.corr()[['Y1','Y2']]
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_target, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Target')
plt.show()

# %%
#Distribucion de las varialbes
sns.pairplot(df)

# %% [markdown]
# ### Modelado

# %% [markdown]
# Vamos a usar una red compartida con dos salidas (cooling and heating load), ya que los dos targets están físicamente relacionados y la red puede aprender representaciones compartidas.
#
# Algunos tips para empezar la arquitectura inicial de la red:
#
# **a. Entrada y salida**
#
# - Entradas: 8 características → tamaño de capa de entrada = 8
# - Salidas: 2 objetivos → tamaño de capa de salida = 2
#
# **b. Capas ocultas**
#
# Por lo general, comienzas poco a poco y vas ampliando:
#
# - Comienza con 1 a 2 capas ocultas.
# - Numero de neuronas: entre el tamaño de entrada y salida (8) y tal vez entre 2 y 4 veces más (16–32–64).
#
# Por ejemplo:
# Input (8)
# ↓
# Dense(64, ReLU)
# ↓
# Dense(32, ReLU)
# ↓
# Dense(2, Linear)
#
# **c. Funcion de activacion**
#
# Comenzar con RELU para capas ocultas
#
# **d. Agregar Regularizacion**
#
# Agregar regularizacion si vemos overfitting (dropout)
#
# **e. Funcion de costo**
#
# MSE
#
# **f. Optimizer**
#
# Adam

# %%
X = df[['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8']].values
y1 = df['Y1'].values  # Heating Load
y2 = df['Y2'].values  # Cooling Load

# %%
X_train, X_test, y1_train, y1_test, y2_train, y2_test = train_test_split(X, y1, y2, test_size=0.2, random_state=42)

# %%
# Estandarizamos los datos
scaler=StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# #### Modelo Baseline

# %%
# Capa de entrada (8 variables)
input_layer = Input(shape=(X_train.shape[1],), name='input_layer')

# Capas ocultas compartidas
layer_dense1_shared=Dense(64 , activation='relu', name='shared_dense_1')(input_layer)
layer_dense2_shared=Dense(32,activation='relu',name='shared_dense_2')(layer_dense1_shared)
layer_dropout1_shared=Dropout(0.2,name='shared_dropout_1')(layer_dense2_shared)

#Estructura para Y1 (Heating Load)
y1_dense_1=Dense(32, activation='relu',name='y1_dense_1')(layer_dropout1_shared)
y1_dropout = Dropout(0.2, name='y1_dropout')(y1_dense_1)
y1_dense2 = Dense(16, activation='relu', name='y1_dense_2')(y1_dropout)
y1_output = Dense(1, name='y1_output')(y1_dense2)

#Estructura para Y2 (Cooling Load)
y2_dense1 = Dense(32, activation='relu', name='y2_dense_1')(layer_dropout1_shared)
y2_dropout = Dropout(0.2, name='y2_dropout')(y2_dense1)
y2_dense3 = Dense(16, activation='relu', name='y2_dense_3')(y2_dropout)
y2_output = Dense(1, name='y2_output')(y2_dense3)

# %%
#  Modelo que contenga la capa de entrada y las capas de salida 
model=Model(inputs=input_layer  ,outputs=[y1_output , y2_output])

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_dense_1      │ (None, 64)        │        576 │ input_layer[0][0] │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_dense_2      │ (None, 32)        │      2,080 │ shared_dense_1[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_dropout_1    │ (None, 32)        │          0 │ shared_dense_2[0… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_dense_1 (Dense)  │ (None, 32)        │      1,056 │ shared_dropout_1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_dense_1 (Dense)  │ (None, 32)        │      1,056 │ shared_dropout_1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_dropout          │ (None, 32)        │          0 │ y1_dense_1[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_dropout          │ (None, 32)        │          0 │ y2_dense_1[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_dense_2 (Dense)  │ (None, 16)        │        528 │ y1_dropout[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_dense_3 (Dense)  │ (None, 16)        │        528 │ y2_dropout[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_output (Dense)   │ (None, 1)         │         17 │ y1_dense_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_output (Dense)   │ (None, 1)         │         17 │ y2_dense_3[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,858 (22.88 KB)
#  Trainable params: 5,858 (22.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compilamos el modelo

model.compile(optimizer='adam', 
              loss={'y1_output': 'mse', 'y2_output': 'mse'}, 
              metrics={'y1_output': 'mae', 'y2_output': 'mae'})

# Entrenamos el modelo
history = model.fit(X_train, [y1_train, y2_train], epochs=200, batch_size=32, 
                    validation_data=(X_test, [y1_test, y2_test]))
# Out:
# Epoch 1/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1229.2063 - y1_output_loss: 562.2479 - y1_output_mae: 21.4631 - y2_output_loss: 665.9305 - y2_output_mae: 24.0111 - val_loss: 1239.4001 - val_y1_output_loss: 555.9462 - val_y1_output_mae: 21.1920 - val_y2_output_loss: 693.7199 - val_y2_output_mae: 24.3586
# Epoch 2/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1023.1055 - y1_output_loss: 444.3775 - y1_output_mae: 18.5998 - y2_output_loss: 575.6591 - y2_output_mae: 22.0352 - val_loss: 848.7991 - val_y1_output_loss: 346.5740 - val_y1_output_mae: 15.8924 - val_y2_output_loss: 510.2856 - val_y2_output_mae: 20.3813
# Epoch 3/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 492.2585 - y1_output_loss: 191.7207 - y1_output_mae: 10.8069 - y2_output_loss: 291.9758 - y2_output_mae: 14.4111 - val_loss: 164.0803 - val_y1_output_loss: 66.6712 - val_y1_output_mae: 6.0843 - val_y2_output_loss: 99.3018 - val_y2_output_mae: 7.1899
# Epoch 4/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 149.1550 - y1_output_loss: 72.4946 - y1_output_mae: 6.4035 - y2_output_loss: 75.5673 - y2_output_mae: 6.4354 - val_loss: 82.2343 - val_y1_output_loss: 38.9949 - val_y1_output_mae: 4.2733 - val_y2_output_loss: 43.7927 - val_y2_output_mae: 4.6444
# Epoch 5/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 113.4711 - y1_output_loss: 53.5919 - y1_output_mae: 5.3723 - y2_output_loss: 57.2544 - y2_output_mae: 5.7134 - val_loss: 65.1738 - val_y1_output_loss: 29.6314 - val_y1_output_mae: 3.7225 - val_y2_output_loss: 35.8484 - val_y2_output_mae: 4.4255
# Epoch 6/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 95.5754 - y1_output_loss: 44.1357 - y1_output_mae: 4.8422 - y2_output_loss: 51.2883 - y2_output_mae: 5.3724 - val_loss: 53.7209 - val_y1_output_loss: 25.4203 - val_y1_output_mae: 3.3725 - val_y2_output_loss: 28.4331 - val_y2_output_mae: 3.8304
# Epoch 7/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 80.6667 - y1_output_loss: 40.2389 - y1_output_mae: 4.5648 - y2_output_loss: 41.1831 - y2_output_mae: 4.9418 - val_loss: 49.0837 - val_y1_output_loss: 22.9166 - val_y1_output_mae: 3.2476 - val_y2_output_loss: 26.3449 - val_y2_output_mae: 3.7399
# Epoch 8/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 74.9218 - y1_output_loss: 36.9865 - y1_output_mae: 4.5192 - y2_output_loss: 38.4119 - y2_output_mae: 4.6531 - val_loss: 45.5099 - val_y1_output_loss: 21.0363 - val_y1_output_mae: 3.1325 - val_y2_output_loss: 24.6169 - val_y2_output_mae: 3.5849
# Epoch 9/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 77.1923 - y1_output_loss: 36.1042 - y1_output_mae: 4.4334 - y2_output_loss: 38.4469 - y2_output_mae: 4.7008 - val_loss: 42.0395 - val_y1_output_loss: 19.5867 - val_y1_output_mae: 3.0196 - val_y2_output_loss: 22.5064 - val_y2_output_mae: 3.4555
# Epoch 10/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 75.3072 - y1_output_loss: 36.8976 - y1_output_mae: 4.4614 - y2_output_loss: 38.2795 - y2_output_mae: 4.7628 - val_loss: 44.4895 - val_y1_output_loss: 20.0912 - val_y1_output_mae: 2.9729 - val_y2_output_loss: 24.4816 - val_y2_output_mae: 3.4346
# Epoch 11/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 70.5400 - y1_output_loss: 33.6757 - y1_output_mae: 4.3215 - y2_output_loss: 36.1655 - y2_output_mae: 4.6718 - val_loss: 37.7939 - val_y1_output_loss: 17.7348 - val_y1_output_mae: 2.8626 - val_y2_output_loss: 20.1299 - val_y2_output_mae: 3.1374
# Epoch 12/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 68.8017 - y1_output_loss: 32.9993 - y1_output_mae: 4.2475 - y2_output_loss: 34.2315 - y2_output_mae: 4.3825 - val_loss: 34.2919 - val_y1_output_loss: 16.0698 - val_y1_output_mae: 2.9598 - val_y2_output_loss: 18.2813 - val_y2_output_mae: 3.2195
# Epoch 13/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 66.2292 - y1_output_loss: 32.0079 - y1_output_mae: 4.2317 - y2_output_loss: 33.3044 - y2_output_mae: 4.4075 - val_loss: 34.4376 - val_y1_output_loss: 16.0971 - val_y1_output_mae: 2.6942 - val_y2_output_loss: 18.4824 - val_y2_output_mae: 2.9568
# Epoch 14/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 61.0058 - y1_output_loss: 29.3305 - y1_output_mae: 3.9907 - y2_output_loss: 31.3258 - y2_output_mae: 4.3042 - val_loss: 30.9435 - val_y1_output_loss: 14.6116 - val_y1_output_mae: 2.6210 - val_y2_output_loss: 16.4672 - val_y2_output_mae: 2.8390
# Epoch 15/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 65.2221 - y1_output_loss: 33.7301 - y1_output_mae: 4.0465 - y2_output_loss: 34.5766 - y2_output_mae: 4.4079 - val_loss: 30.2793 - val_y1_output_loss: 14.0077 - val_y1_output_mae: 2.6027 - val_y2_output_loss: 16.3671 - val_y2_output_mae: 2.8427
# Epoch 16/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 56.5425 - y1_output_loss: 25.8963 - y1_output_mae: 3.8474 - y2_output_loss: 29.7580 - y2_output_mae: 4.2111 - val_loss: 27.7375 - val_y1_output_loss: 12.9209 - val_y1_output_mae: 2.5161 - val_y2_output_loss: 14.9367 - val_y2_output_mae: 2.7035
# Epoch 17/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 55.1803 - y1_output_loss: 27.3590 - y1_output_mae: 3.9298 - y2_output_loss: 26.9022 - y2_output_mae: 4.0323 - val_loss: 27.2651 - val_y1_output_loss: 12.7157 - val_y1_output_mae: 2.4571 - val_y2_output_loss: 14.6388 - val_y2_output_mae: 2.7336
# Epoch 18/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 57.5370 - y1_output_loss: 26.8016 - y1_output_mae: 3.8590 - y2_output_loss: 31.5382 - y2_output_mae: 4.2274 - val_loss: 28.0269 - val_y1_output_loss: 12.4923 - val_y1_output_mae: 2.4165 - val_y2_output_loss: 15.5990 - val_y2_output_mae: 2.6324
# Epoch 19/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 51.2889 - y1_output_loss: 26.0906 - y1_output_mae: 3.7763 - y2_output_loss: 26.4028 - y2_output_mae: 3.7928 - val_loss: 29.9481 - val_y1_output_loss: 13.7615 - val_y1_output_mae: 2.6326 - val_y2_output_loss: 16.3429 - val_y2_output_mae: 2.7439
# Epoch 20/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 51.0254 - y1_output_loss: 23.9538 - y1_output_mae: 3.5559 - y2_output_loss: 27.7720 - y2_output_mae: 3.9457 - val_loss: 24.5699 - val_y1_output_loss: 11.0504 - val_y1_output_mae: 2.3812 - val_y2_output_loss: 13.5769 - val_y2_output_mae: 2.5237
# Epoch 21/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 49.6284 - y1_output_loss: 25.4969 - y1_output_mae: 3.7121 - y2_output_loss: 26.4717 - y2_output_mae: 3.9237 - val_loss: 25.3017 - val_y1_output_loss: 11.6235 - val_y1_output_mae: 2.3969 - val_y2_output_loss: 13.7498 - val_y2_output_mae: 2.5236
# Epoch 22/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 48.1426 - y1_output_loss: 24.3322 - y1_output_mae: 3.5670 - y2_output_loss: 24.7244 - y2_output_mae: 3.7384 - val_loss: 23.2465 - val_y1_output_loss: 10.5225 - val_y1_output_mae: 2.3449 - val_y2_output_loss: 12.7182 - val_y2_output_mae: 2.4819
# Epoch 23/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46.7403 - y1_output_loss: 20.3569 - y1_output_mae: 3.4588 - y2_output_loss: 26.1943 - y2_output_mae: 3.7760 - val_loss: 23.1768 - val_y1_output_loss: 10.5860 - val_y1_output_mae: 2.3631 - val_y2_output_loss: 12.5256 - val_y2_output_mae: 2.5428
# Epoch 24/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 49.5122 - y1_output_loss: 23.2336 - y1_output_mae: 3.5192 - y2_output_loss: 26.0840 - y2_output_mae: 3.8502 - val_loss: 28.7547 - val_y1_output_loss: 12.4900 - val_y1_output_mae: 2.5294 - val_y2_output_loss: 16.4102 - val_y2_output_mae: 2.7849
# Epoch 25/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 49.7298 - y1_output_loss: 22.4207 - y1_output_mae: 3.5702 - y2_output_loss: 26.8788 - y2_output_mae: 3.8203 - val_loss: 23.9556 - val_y1_output_loss: 10.8254 - val_y1_output_mae: 2.3236 - val_y2_output_loss: 13.2209 - val_y2_output_mae: 2.4818
# Epoch 26/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 44.8396 - y1_output_loss: 21.1235 - y1_output_mae: 3.4569 - y2_output_loss: 23.6282 - y2_output_mae: 3.6193 - val_loss: 28.8503 - val_y1_output_loss: 11.9040 - val_y1_output_mae: 2.4844 - val_y2_output_loss: 17.1709 - val_y2_output_mae: 2.9051
# Epoch 27/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 44.0816 - y1_output_loss: 21.3519 - y1_output_mae: 3.4851 - y2_output_loss: 21.5143 - y2_output_mae: 3.5840 - val_loss: 21.9155 - val_y1_output_loss: 9.7703 - val_y1_output_mae: 2.1909 - val_y2_output_loss: 12.1335 - val_y2_output_mae: 2.3474
# Epoch 28/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 43.9092 - y1_output_loss: 19.8399 - y1_output_mae: 3.3425 - y2_output_loss: 23.6358 - y2_output_mae: 3.6275 - val_loss: 23.0469 - val_y1_output_loss: 10.2757 - val_y1_output_mae: 2.2388 - val_y2_output_loss: 12.7948 - val_y2_output_mae: 2.4113
# Epoch 29/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 44.2914 - y1_output_loss: 19.9405 - y1_output_mae: 3.3053 - y2_output_loss: 23.2687 - y2_output_mae: 3.6999 - val_loss: 22.0912 - val_y1_output_loss: 9.9025 - val_y1_output_mae: 2.1858 - val_y2_output_loss: 12.1750 - val_y2_output_mae: 2.3495
# Epoch 30/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 41.1222 - y1_output_loss: 21.1357 - y1_output_mae: 3.3387 - y2_output_loss: 19.6337 - y2_output_mae: 3.3588 - val_loss: 20.6848 - val_y1_output_loss: 9.6681 - val_y1_output_mae: 2.1792 - val_y2_output_loss: 10.9683 - val_y2_output_mae: 2.3325
# Epoch 31/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 43.3794 - y1_output_loss: 18.9574 - y1_output_mae: 3.2828 - y2_output_loss: 23.0379 - y2_output_mae: 3.5792 - val_loss: 20.2088 - val_y1_output_loss: 9.1758 - val_y1_output_mae: 2.1492 - val_y2_output_loss: 10.9817 - val_y2_output_mae: 2.3171
# Epoch 32/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 44.3255 - y1_output_loss: 21.0204 - y1_output_mae: 3.4657 - y2_output_loss: 23.3349 - y2_output_mae: 3.6367 - val_loss: 20.4248 - val_y1_output_loss: 8.9709 - val_y1_output_mae: 2.1267 - val_y2_output_loss: 11.4194 - val_y2_output_mae: 2.3096
# Epoch 33/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 42.9839 - y1_output_loss: 20.4671 - y1_output_mae: 3.3340 - y2_output_loss: 22.1957 - y2_output_mae: 3.5039 - val_loss: 20.3946 - val_y1_output_loss: 9.0712 - val_y1_output_mae: 2.1790 - val_y2_output_loss: 11.3068 - val_y2_output_mae: 2.3188
# Epoch 34/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46.9102 - y1_output_loss: 21.2542 - y1_output_mae: 3.3667 - y2_output_loss: 25.3741 - y2_output_mae: 3.7662 - val_loss: 19.1140 - val_y1_output_loss: 8.7926 - val_y1_output_mae: 2.0456 - val_y2_output_loss: 10.2822 - val_y2_output_mae: 2.1783
# Epoch 35/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 42.8788 - y1_output_loss: 19.8336 - y1_output_mae: 3.3247 - y2_output_loss: 22.7616 - y2_output_mae: 3.4885 - val_loss: 21.3622 - val_y1_output_loss: 9.5153 - val_y1_output_mae: 2.1216 - val_y2_output_loss: 11.7835 - val_y2_output_mae: 2.2786
# Epoch 36/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.6501 - y1_output_loss: 17.4344 - y1_output_mae: 3.1759 - y2_output_loss: 22.4103 - y2_output_mae: 3.6107 - val_loss: 19.5010 - val_y1_output_loss: 8.6808 - val_y1_output_mae: 2.0682 - val_y2_output_loss: 10.7705 - val_y2_output_mae: 2.2302
# Epoch 37/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 42.6489 - y1_output_loss: 17.5068 - y1_output_mae: 3.0945 - y2_output_loss: 23.7153 - y2_output_mae: 3.6815 - val_loss: 18.4095 - val_y1_output_loss: 8.3102 - val_y1_output_mae: 2.0071 - val_y2_output_loss: 9.9619 - val_y2_output_mae: 2.2175
# Epoch 38/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 42.8193 - y1_output_loss: 21.5139 - y1_output_mae: 3.3734 - y2_output_loss: 21.2202 - y2_output_mae: 3.4790 - val_loss: 21.3707 - val_y1_output_loss: 9.4155 - val_y1_output_mae: 2.0806 - val_y2_output_loss: 11.9412 - val_y2_output_mae: 2.3011
# Epoch 39/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 43.3107 - y1_output_loss: 20.8324 - y1_output_mae: 3.3623 - y2_output_loss: 21.5731 - y2_output_mae: 3.5290 - val_loss: 18.9924 - val_y1_output_loss: 8.5104 - val_y1_output_mae: 2.0433 - val_y2_output_loss: 10.4420 - val_y2_output_mae: 2.1943
# Epoch 40/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 41.8350 - y1_output_loss: 20.1766 - y1_output_mae: 3.3410 - y2_output_loss: 22.9284 - y2_output_mae: 3.4691 - val_loss: 20.0652 - val_y1_output_loss: 9.0565 - val_y1_output_mae: 2.0944 - val_y2_output_loss: 10.9773 - val_y2_output_mae: 2.2411
# Epoch 41/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 38.4029 - y1_output_loss: 18.8255 - y1_output_mae: 3.1910 - y2_output_loss: 20.6741 - y2_output_mae: 3.3355 - val_loss: 17.7255 - val_y1_output_loss: 7.9562 - val_y1_output_mae: 1.9418 - val_y2_output_loss: 9.6890 - val_y2_output_mae: 2.1968
# Epoch 42/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 42.3946 - y1_output_loss: 17.6730 - y1_output_mae: 3.1419 - y2_output_loss: 23.7464 - y2_output_mae: 3.5997 - val_loss: 18.4915 - val_y1_output_loss: 8.6304 - val_y1_output_mae: 1.9921 - val_y2_output_loss: 9.8319 - val_y2_output_mae: 2.1251
# Epoch 43/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 41.4211 - y1_output_loss: 19.8516 - y1_output_mae: 3.2501 - y2_output_loss: 21.9589 - y2_output_mae: 3.3704 - val_loss: 19.6532 - val_y1_output_loss: 7.9932 - val_y1_output_mae: 1.9200 - val_y2_output_loss: 11.6641 - val_y2_output_mae: 2.3029
# Epoch 44/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 41.3625 - y1_output_loss: 19.0952 - y1_output_mae: 3.2295 - y2_output_loss: 23.1116 - y2_output_mae: 3.4730 - val_loss: 22.2853 - val_y1_output_loss: 9.9136 - val_y1_output_mae: 2.2916 - val_y2_output_loss: 12.5074 - val_y2_output_mae: 2.4559
# Epoch 45/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.9266 - y1_output_loss: 18.3311 - y1_output_mae: 3.1206 - y2_output_loss: 22.6173 - y2_output_mae: 3.5018 - val_loss: 21.8782 - val_y1_output_loss: 9.9785 - val_y1_output_mae: 2.2537 - val_y2_output_loss: 11.9623 - val_y2_output_mae: 2.3542
# Epoch 46/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.5031 - y1_output_loss: 18.1768 - y1_output_mae: 3.1586 - y2_output_loss: 23.0449 - y2_output_mae: 3.6252 - val_loss: 23.1555 - val_y1_output_loss: 11.3776 - val_y1_output_mae: 2.5397 - val_y2_output_loss: 11.9313 - val_y2_output_mae: 2.3858
# Epoch 47/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 41.0898 - y1_output_loss: 19.0677 - y1_output_mae: 3.2502 - y2_output_loss: 22.3701 - y2_output_mae: 3.4683 - val_loss: 17.6702 - val_y1_output_loss: 7.7871 - val_y1_output_mae: 1.9505 - val_y2_output_loss: 9.9021 - val_y2_output_mae: 2.1379
# Epoch 48/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.0673 - y1_output_loss: 19.6178 - y1_output_mae: 3.1949 - y2_output_loss: 20.9215 - y2_output_mae: 3.3731 - val_loss: 23.1765 - val_y1_output_loss: 11.9600 - val_y1_output_mae: 2.6330 - val_y2_output_loss: 11.3519 - val_y2_output_mae: 2.3349
# Epoch 49/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.9617 - y1_output_loss: 20.4292 - y1_output_mae: 3.2942 - y2_output_loss: 20.2286 - y2_output_mae: 3.3534 - val_loss: 24.3567 - val_y1_output_loss: 9.7731 - val_y1_output_mae: 2.2984 - val_y2_output_loss: 14.7354 - val_y2_output_mae: 2.7268
# Epoch 50/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 38.0903 - y1_output_loss: 18.4816 - y1_output_mae: 3.2088 - y2_output_loss: 18.8964 - y2_output_mae: 3.2706 - val_loss: 17.6210 - val_y1_output_loss: 8.3163 - val_y1_output_mae: 2.0359 - val_y2_output_loss: 9.2363 - val_y2_output_mae: 2.0437
# Epoch 51/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.9457 - y1_output_loss: 21.1184 - y1_output_mae: 3.3165 - y2_output_loss: 21.6335 - y2_output_mae: 3.3985 - val_loss: 19.2157 - val_y1_output_loss: 8.5055 - val_y1_output_mae: 2.0965 - val_y2_output_loss: 10.6847 - val_y2_output_mae: 2.2320
# Epoch 52/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 38.7482 - y1_output_loss: 18.9149 - y1_output_mae: 3.2831 - y2_output_loss: 19.3387 - y2_output_mae: 3.3158 - val_loss: 19.0463 - val_y1_output_loss: 7.7379 - val_y1_output_mae: 1.9854 - val_y2_output_loss: 11.3481 - val_y2_output_mae: 2.3304
# Epoch 53/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 39.2514 - y1_output_loss: 18.1839 - y1_output_mae: 3.1587 - y2_output_loss: 21.0541 - y2_output_mae: 3.4567 - val_loss: 19.1186 - val_y1_output_loss: 9.3957 - val_y1_output_mae: 2.2305 - val_y2_output_loss: 9.7795 - val_y2_output_mae: 2.1109
# Epoch 54/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37.7813 - y1_output_loss: 18.0086 - y1_output_mae: 3.1605 - y2_output_loss: 18.8394 - y2_output_mae: 3.2817 - val_loss: 22.0630 - val_y1_output_loss: 9.8131 - val_y1_output_mae: 2.4302 - val_y2_output_loss: 12.4292 - val_y2_output_mae: 2.5338
# Epoch 55/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 39.3211 - y1_output_loss: 18.4663 - y1_output_mae: 3.1695 - y2_output_loss: 21.2427 - y2_output_mae: 3.4577 - val_loss: 22.6645 - val_y1_output_loss: 8.3912 - val_y1_output_mae: 2.1772 - val_y2_output_loss: 14.4851 - val_y2_output_mae: 2.7632
# Epoch 56/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 38.9338 - y1_output_loss: 17.9226 - y1_output_mae: 3.1199 - y2_output_loss: 20.6393 - y2_output_mae: 3.3302 - val_loss: 16.6282 - val_y1_output_loss: 7.8600 - val_y1_output_mae: 2.0453 - val_y2_output_loss: 8.7921 - val_y2_output_mae: 2.0208
# Epoch 57/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.6544 - y1_output_loss: 16.4948 - y1_output_mae: 2.9316 - y2_output_loss: 18.4087 - y2_output_mae: 3.2368 - val_loss: 20.0981 - val_y1_output_loss: 9.2710 - val_y1_output_mae: 2.3222 - val_y2_output_loss: 10.9712 - val_y2_output_mae: 2.2940
# Epoch 58/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.5260 - y1_output_loss: 18.2957 - y1_output_mae: 3.0625 - y2_output_loss: 22.3480 - y2_output_mae: 3.4882 - val_loss: 19.6083 - val_y1_output_loss: 7.6109 - val_y1_output_mae: 1.9553 - val_y2_output_loss: 12.0973 - val_y2_output_mae: 2.3739
# Epoch 59/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37.8893 - y1_output_loss: 17.5690 - y1_output_mae: 3.0582 - y2_output_loss: 19.8107 - y2_output_mae: 3.2558 - val_loss: 15.8889 - val_y1_output_loss: 6.8535 - val_y1_output_mae: 1.8586 - val_y2_output_loss: 8.8723 - val_y2_output_mae: 2.2748
# Epoch 60/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 42.1247 - y1_output_loss: 19.6227 - y1_output_mae: 3.2844 - y2_output_loss: 20.9862 - y2_output_mae: 3.4026 - val_loss: 18.5476 - val_y1_output_loss: 7.8466 - val_y1_output_mae: 1.9898 - val_y2_output_loss: 10.7435 - val_y2_output_mae: 2.2060
# Epoch 61/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.0732 - y1_output_loss: 15.1054 - y1_output_mae: 2.9357 - y2_output_loss: 18.4247 - y2_output_mae: 3.1707 - val_loss: 20.9052 - val_y1_output_loss: 9.2065 - val_y1_output_mae: 2.2665 - val_y2_output_loss: 11.8264 - val_y2_output_mae: 2.3261
# Epoch 62/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.9499 - y1_output_loss: 17.0544 - y1_output_mae: 3.1201 - y2_output_loss: 19.0028 - y2_output_mae: 3.3008 - val_loss: 15.9074 - val_y1_output_loss: 7.1148 - val_y1_output_mae: 1.9143 - val_y2_output_loss: 8.7929 - val_y2_output_mae: 1.9946
# Epoch 63/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.8190 - y1_output_loss: 17.6598 - y1_output_mae: 3.0015 - y2_output_loss: 20.8472 - y2_output_mae: 3.2273 - val_loss: 17.6592 - val_y1_output_loss: 7.6922 - val_y1_output_mae: 2.0851 - val_y2_output_loss: 10.0319 - val_y2_output_mae: 2.1385
# Epoch 64/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.7878 - y1_output_loss: 16.4503 - y1_output_mae: 3.0099 - y2_output_loss: 18.4208 - y2_output_mae: 3.2600 - val_loss: 15.5581 - val_y1_output_loss: 6.8785 - val_y1_output_mae: 1.9214 - val_y2_output_loss: 8.6977 - val_y2_output_mae: 1.9959
# Epoch 65/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 35.8536 - y1_output_loss: 16.6041 - y1_output_mae: 2.9396 - y2_output_loss: 19.7257 - y2_output_mae: 3.1882 - val_loss: 14.6836 - val_y1_output_loss: 6.3868 - val_y1_output_mae: 1.7856 - val_y2_output_loss: 8.1521 - val_y2_output_mae: 2.1740
# Epoch 66/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 39.1788 - y1_output_loss: 17.9288 - y1_output_mae: 3.1436 - y2_output_loss: 20.4472 - y2_output_mae: 3.4160 - val_loss: 16.2663 - val_y1_output_loss: 6.5703 - val_y1_output_mae: 1.8515 - val_y2_output_loss: 9.7044 - val_y2_output_mae: 2.0596
# Epoch 67/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 38.6028 - y1_output_loss: 17.9346 - y1_output_mae: 3.0471 - y2_output_loss: 22.4801 - y2_output_mae: 3.3087 - val_loss: 18.3305 - val_y1_output_loss: 8.3517 - val_y1_output_mae: 2.2031 - val_y2_output_loss: 10.0683 - val_y2_output_mae: 2.0862
# Epoch 68/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 35.2728 - y1_output_loss: 17.1947 - y1_output_mae: 2.9956 - y2_output_loss: 18.1789 - y2_output_mae: 3.1633 - val_loss: 17.6080 - val_y1_output_loss: 7.3205 - val_y1_output_mae: 1.9789 - val_y2_output_loss: 10.3794 - val_y2_output_mae: 2.1344
# Epoch 69/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33.6230 - y1_output_loss: 16.2109 - y1_output_mae: 2.8915 - y2_output_loss: 17.4273 - y2_output_mae: 3.1301 - val_loss: 21.8573 - val_y1_output_loss: 9.2788 - val_y1_output_mae: 2.3470 - val_y2_output_loss: 12.7884 - val_y2_output_mae: 2.4365
# Epoch 70/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 38.4292 - y1_output_loss: 19.2634 - y1_output_mae: 3.2259 - y2_output_loss: 18.5464 - y2_output_mae: 3.2610 - val_loss: 21.1027 - val_y1_output_loss: 9.4511 - val_y1_output_mae: 2.3872 - val_y2_output_loss: 11.7919 - val_y2_output_mae: 2.2989
# Epoch 71/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 35.2981 - y1_output_loss: 16.5931 - y1_output_mae: 2.9652 - y2_output_loss: 19.1048 - y2_output_mae: 3.2717 - val_loss: 23.6215 - val_y1_output_loss: 10.4656 - val_y1_output_mae: 2.5556 - val_y2_output_loss: 13.3890 - val_y2_output_mae: 2.5766
# Epoch 72/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.8050 - y1_output_loss: 18.2151 - y1_output_mae: 3.1672 - y2_output_loss: 18.9717 - y2_output_mae: 3.2317 - val_loss: 20.3518 - val_y1_output_loss: 8.4441 - val_y1_output_mae: 2.2681 - val_y2_output_loss: 12.0987 - val_y2_output_mae: 2.4054
# Epoch 73/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37.1496 - y1_output_loss: 17.3696 - y1_output_mae: 3.0029 - y2_output_loss: 19.3558 - y2_output_mae: 3.2627 - val_loss: 16.6251 - val_y1_output_loss: 6.7911 - val_y1_output_mae: 1.9749 - val_y2_output_loss: 9.9452 - val_y2_output_mae: 2.1318
# Epoch 74/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.5379 - y1_output_loss: 17.6978 - y1_output_mae: 3.0689 - y2_output_loss: 20.7223 - y2_output_mae: 3.1920 - val_loss: 23.4136 - val_y1_output_loss: 11.7634 - val_y1_output_mae: 2.7186 - val_y2_output_loss: 11.9057 - val_y2_output_mae: 2.4031
# Epoch 75/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.9736 - y1_output_loss: 18.5138 - y1_output_mae: 3.1830 - y2_output_loss: 21.3717 - y2_output_mae: 3.4196 - val_loss: 15.4782 - val_y1_output_loss: 6.6176 - val_y1_output_mae: 1.8353 - val_y2_output_loss: 8.7239 - val_y2_output_mae: 2.2501
# Epoch 76/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.7113 - y1_output_loss: 16.7142 - y1_output_mae: 3.0748 - y2_output_loss: 19.4074 - y2_output_mae: 3.2768 - val_loss: 15.0437 - val_y1_output_loss: 6.0348 - val_y1_output_mae: 1.7723 - val_y2_output_loss: 9.0015 - val_y2_output_mae: 2.0100
# Epoch 77/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 35.7591 - y1_output_loss: 17.7645 - y1_output_mae: 3.0764 - y2_output_loss: 19.1521 - y2_output_mae: 3.1980 - val_loss: 15.7570 - val_y1_output_loss: 6.5911 - val_y1_output_mae: 1.8799 - val_y2_output_loss: 9.2043 - val_y2_output_mae: 2.0329
# Epoch 78/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37.4316 - y1_output_loss: 16.8804 - y1_output_mae: 3.0110 - y2_output_loss: 20.2160 - y2_output_mae: 3.3059 - val_loss: 15.7822 - val_y1_output_loss: 7.4126 - val_y1_output_mae: 2.1315 - val_y2_output_loss: 8.3929 - val_y2_output_mae: 1.9559
# Epoch 79/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 31.9765 - y1_output_loss: 15.0133 - y1_output_mae: 2.8488 - y2_output_loss: 16.8763 - y2_output_mae: 3.0831 - val_loss: 13.9709 - val_y1_output_loss: 5.8127 - val_y1_output_mae: 1.7691 - val_y2_output_loss: 8.1425 - val_y2_output_mae: 1.9280
# Epoch 80/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.5115 - y1_output_loss: 16.0961 - y1_output_mae: 2.9025 - y2_output_loss: 20.5007 - y2_output_mae: 3.1898 - val_loss: 13.5158 - val_y1_output_loss: 5.6446 - val_y1_output_mae: 1.7208 - val_y2_output_loss: 7.8249 - val_y2_output_mae: 1.8937
# Epoch 81/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 35.6767 - y1_output_loss: 16.2479 - y1_output_mae: 3.0039 - y2_output_loss: 18.9986 - y2_output_mae: 3.2417 - val_loss: 16.0010 - val_y1_output_loss: 6.7256 - val_y1_output_mae: 1.9967 - val_y2_output_loss: 9.2985 - val_y2_output_mae: 2.0319
# Epoch 82/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 35.2297 - y1_output_loss: 16.4229 - y1_output_mae: 3.0001 - y2_output_loss: 18.4624 - y2_output_mae: 3.1037 - val_loss: 16.2408 - val_y1_output_loss: 7.3994 - val_y1_output_mae: 2.1360 - val_y2_output_loss: 8.9362 - val_y2_output_mae: 1.9725
# Epoch 83/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.5833 - y1_output_loss: 17.1426 - y1_output_mae: 3.0448 - y2_output_loss: 16.5152 - y2_output_mae: 3.0840 - val_loss: 17.8341 - val_y1_output_loss: 6.9868 - val_y1_output_mae: 1.9533 - val_y2_output_loss: 10.9272 - val_y2_output_mae: 2.2123
# Epoch 84/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 31.7361 - y1_output_loss: 14.1977 - y1_output_mae: 2.7425 - y2_output_loss: 18.9476 - y2_output_mae: 3.1011 - val_loss: 19.7437 - val_y1_output_loss: 8.2165 - val_y1_output_mae: 2.2672 - val_y2_output_loss: 11.7475 - val_y2_output_mae: 2.3650
# Epoch 85/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.5078 - y1_output_loss: 15.1547 - y1_output_mae: 2.9638 - y2_output_loss: 20.0806 - y2_output_mae: 3.2941 - val_loss: 26.6880 - val_y1_output_loss: 9.5097 - val_y1_output_mae: 2.4646 - val_y2_output_loss: 17.5830 - val_y2_output_mae: 3.0535
# Epoch 86/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33.1390 - y1_output_loss: 15.5450 - y1_output_mae: 2.9307 - y2_output_loss: 16.5575 - y2_output_mae: 3.0681 - val_loss: 14.4800 - val_y1_output_loss: 6.2470 - val_y1_output_mae: 1.9233 - val_y2_output_loss: 8.2965 - val_y2_output_mae: 1.9356
# Epoch 87/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.1009 - y1_output_loss: 15.3030 - y1_output_mae: 2.8616 - y2_output_loss: 18.6476 - y2_output_mae: 3.1391 - val_loss: 17.2018 - val_y1_output_loss: 6.4925 - val_y1_output_mae: 1.9721 - val_y2_output_loss: 10.8392 - val_y2_output_mae: 2.2905
# Epoch 88/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.4937 - y1_output_loss: 16.4807 - y1_output_mae: 2.9335 - y2_output_loss: 18.5528 - y2_output_mae: 3.2078 - val_loss: 15.3527 - val_y1_output_loss: 6.7194 - val_y1_output_mae: 1.9808 - val_y2_output_loss: 8.7045 - val_y2_output_mae: 1.9443
# Epoch 89/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 31.8775 - y1_output_loss: 15.6332 - y1_output_mae: 2.8635 - y2_output_loss: 17.2134 - y2_output_mae: 3.0726 - val_loss: 16.8617 - val_y1_output_loss: 6.7879 - val_y1_output_mae: 2.0106 - val_y2_output_loss: 10.2368 - val_y2_output_mae: 2.1745
# Epoch 90/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33.1483 - y1_output_loss: 13.4947 - y1_output_mae: 2.7545 - y2_output_loss: 18.6058 - y2_output_mae: 3.1342 - val_loss: 18.2384 - val_y1_output_loss: 7.5558 - val_y1_output_mae: 2.1042 - val_y2_output_loss: 10.8098 - val_y2_output_mae: 2.2241
# Epoch 91/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.8058 - y1_output_loss: 17.3632 - y1_output_mae: 3.0719 - y2_output_loss: 17.6912 - y2_output_mae: 3.0209 - val_loss: 18.0681 - val_y1_output_loss: 6.9903 - val_y1_output_mae: 1.9901 - val_y2_output_loss: 11.2450 - val_y2_output_mae: 2.2600
# Epoch 92/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 31.9542 - y1_output_loss: 13.7526 - y1_output_mae: 2.8151 - y2_output_loss: 17.3841 - y2_output_mae: 3.1316 - val_loss: 20.0898 - val_y1_output_loss: 7.0610 - val_y1_output_mae: 2.0719 - val_y2_output_loss: 13.2527 - val_y2_output_mae: 2.5991
# Epoch 93/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 30.3960 - y1_output_loss: 15.2486 - y1_output_mae: 2.8673 - y2_output_loss: 14.7746 - y2_output_mae: 2.8808 - val_loss: 14.1420 - val_y1_output_loss: 6.2044 - val_y1_output_mae: 1.9004 - val_y2_output_loss: 8.0175 - val_y2_output_mae: 1.8830
# Epoch 94/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 27.5915 - y1_output_loss: 12.3937 - y1_output_mae: 2.6702 - y2_output_loss: 14.4753 - y2_output_mae: 2.9425 - val_loss: 15.1629 - val_y1_output_loss: 6.0652 - val_y1_output_mae: 1.9314 - val_y2_output_loss: 9.1980 - val_y2_output_mae: 2.1062
# Epoch 95/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32.9530 - y1_output_loss: 15.2555 - y1_output_mae: 2.8531 - y2_output_loss: 17.2509 - y2_output_mae: 3.1171 - val_loss: 15.4260 - val_y1_output_loss: 6.5524 - val_y1_output_mae: 1.9987 - val_y2_output_loss: 8.9229 - val_y2_output_mae: 2.0333
# Epoch 96/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 30.7159 - y1_output_loss: 14.8385 - y1_output_mae: 2.7669 - y2_output_loss: 15.6255 - y2_output_mae: 2.9373 - val_loss: 14.0222 - val_y1_output_loss: 5.6555 - val_y1_output_mae: 1.7642 - val_y2_output_loss: 8.4087 - val_y2_output_mae: 1.9347
# Epoch 97/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.3885 - y1_output_loss: 14.2991 - y1_output_mae: 2.6578 - y2_output_loss: 15.6241 - y2_output_mae: 2.9482 - val_loss: 15.2919 - val_y1_output_loss: 6.8094 - val_y1_output_mae: 2.0320 - val_y2_output_loss: 8.5989 - val_y2_output_mae: 1.9777
# Epoch 98/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.5399 - y1_output_loss: 11.6253 - y1_output_mae: 2.5943 - y2_output_loss: 15.1890 - y2_output_mae: 2.9749 - val_loss: 15.8291 - val_y1_output_loss: 7.0024 - val_y1_output_mae: 2.0763 - val_y2_output_loss: 8.9338 - val_y2_output_mae: 1.9959
# Epoch 99/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32.0460 - y1_output_loss: 14.7605 - y1_output_mae: 2.8373 - y2_output_loss: 16.8556 - y2_output_mae: 3.0516 - val_loss: 20.4640 - val_y1_output_loss: 8.7354 - val_y1_output_mae: 2.4249 - val_y2_output_loss: 11.9372 - val_y2_output_mae: 2.5087
# Epoch 100/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 31.2580 - y1_output_loss: 14.1826 - y1_output_mae: 2.8337 - y2_output_loss: 16.2954 - y2_output_mae: 2.9873 - val_loss: 19.9316 - val_y1_output_loss: 8.1621 - val_y1_output_mae: 2.3478 - val_y2_output_loss: 12.0280 - val_y2_output_mae: 2.5178
# Epoch 101/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.2087 - y1_output_loss: 14.3831 - y1_output_mae: 2.7512 - y2_output_loss: 14.3284 - y2_output_mae: 2.8010 - val_loss: 17.8387 - val_y1_output_loss: 7.4370 - val_y1_output_mae: 2.2057 - val_y2_output_loss: 10.5943 - val_y2_output_mae: 2.2954
# Epoch 102/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32.1055 - y1_output_loss: 14.7847 - y1_output_mae: 2.8663 - y2_output_loss: 17.0154 - y2_output_mae: 3.0520 - val_loss: 18.8314 - val_y1_output_loss: 6.4134 - val_y1_output_mae: 2.0010 - val_y2_output_loss: 12.6677 - val_y2_output_mae: 2.5176
# Epoch 103/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 30.5726 - y1_output_loss: 14.5634 - y1_output_mae: 2.8495 - y2_output_loss: 15.5129 - y2_output_mae: 2.9195 - val_loss: 18.4421 - val_y1_output_loss: 8.8388 - val_y1_output_mae: 2.3792 - val_y2_output_loss: 9.8610 - val_y2_output_mae: 2.1608
# Epoch 104/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.8281 - y1_output_loss: 14.0517 - y1_output_mae: 2.6663 - y2_output_loss: 17.1844 - y2_output_mae: 2.8150 - val_loss: 14.6368 - val_y1_output_loss: 5.7280 - val_y1_output_mae: 1.8507 - val_y2_output_loss: 9.0194 - val_y2_output_mae: 2.0437
# Epoch 105/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32.7660 - y1_output_loss: 14.9092 - y1_output_mae: 2.8227 - y2_output_loss: 16.9165 - y2_output_mae: 3.0428 - val_loss: 19.3289 - val_y1_output_loss: 9.0565 - val_y1_output_mae: 2.4640 - val_y2_output_loss: 10.5324 - val_y2_output_mae: 2.3485
# Epoch 106/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.3287 - y1_output_loss: 13.0392 - y1_output_mae: 2.6684 - y2_output_loss: 15.6979 - y2_output_mae: 2.9224 - val_loss: 14.2605 - val_y1_output_loss: 6.4595 - val_y1_output_mae: 2.0469 - val_y2_output_loss: 7.9463 - val_y2_output_mae: 1.9513
# Epoch 107/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.4892 - y1_output_loss: 14.6416 - y1_output_mae: 2.7757 - y2_output_loss: 14.6226 - y2_output_mae: 2.8638 - val_loss: 12.3698 - val_y1_output_loss: 4.9571 - val_y1_output_mae: 1.7137 - val_y2_output_loss: 7.4749 - val_y2_output_mae: 1.8722
# Epoch 108/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.3615 - y1_output_loss: 11.9804 - y1_output_mae: 2.6118 - y2_output_loss: 15.7102 - y2_output_mae: 2.9123 - val_loss: 11.5563 - val_y1_output_loss: 4.8610 - val_y1_output_mae: 1.6258 - val_y2_output_loss: 6.6330 - val_y2_output_mae: 1.8375
# Epoch 109/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.4401 - y1_output_loss: 13.9906 - y1_output_mae: 2.6857 - y2_output_loss: 15.8753 - y2_output_mae: 2.9349 - val_loss: 12.6166 - val_y1_output_loss: 5.4818 - val_y1_output_mae: 1.8596 - val_y2_output_loss: 7.1493 - val_y2_output_mae: 1.8099
# Epoch 110/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 30.6230 - y1_output_loss: 13.7389 - y1_output_mae: 2.7118 - y2_output_loss: 16.3352 - y2_output_mae: 2.9795 - val_loss: 14.9686 - val_y1_output_loss: 5.2751 - val_y1_output_mae: 1.8409 - val_y2_output_loss: 9.8141 - val_y2_output_mae: 2.2333
# Epoch 111/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.9993 - y1_output_loss: 13.2776 - y1_output_mae: 2.6699 - y2_output_loss: 16.3780 - y2_output_mae: 2.8964 - val_loss: 18.5885 - val_y1_output_loss: 7.3781 - val_y1_output_mae: 2.1798 - val_y2_output_loss: 11.4573 - val_y2_output_mae: 2.3787
# Epoch 112/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.1404 - y1_output_loss: 14.1591 - y1_output_mae: 2.5396 - y2_output_loss: 15.2298 - y2_output_mae: 2.9285 - val_loss: 18.2559 - val_y1_output_loss: 8.2116 - val_y1_output_mae: 2.3044 - val_y2_output_loss: 10.3297 - val_y2_output_mae: 2.2637
# Epoch 113/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.3505 - y1_output_loss: 13.1638 - y1_output_mae: 2.7041 - y2_output_loss: 15.3274 - y2_output_mae: 2.8758 - val_loss: 16.8755 - val_y1_output_loss: 7.4436 - val_y1_output_mae: 2.2235 - val_y2_output_loss: 9.6635 - val_y2_output_mae: 2.1544
# Epoch 114/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.0401 - y1_output_loss: 12.7774 - y1_output_mae: 2.5991 - y2_output_loss: 14.5678 - y2_output_mae: 2.8515 - val_loss: 11.7807 - val_y1_output_loss: 4.7933 - val_y1_output_mae: 1.6586 - val_y2_output_loss: 7.0366 - val_y2_output_mae: 1.7902
# Epoch 115/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.0034 - y1_output_loss: 12.5023 - y1_output_mae: 2.5493 - y2_output_loss: 14.1580 - y2_output_mae: 2.7594 - val_loss: 14.8161 - val_y1_output_loss: 6.8808 - val_y1_output_mae: 2.1056 - val_y2_output_loss: 8.0878 - val_y2_output_mae: 1.9666
# Epoch 116/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.8838 - y1_output_loss: 12.7809 - y1_output_mae: 2.5965 - y2_output_loss: 13.8935 - y2_output_mae: 2.7708 - val_loss: 15.0789 - val_y1_output_loss: 6.3880 - val_y1_output_mae: 2.0317 - val_y2_output_loss: 8.8526 - val_y2_output_mae: 2.0620
# Epoch 117/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.6549 - y1_output_loss: 13.0279 - y1_output_mae: 2.5119 - y2_output_loss: 14.3367 - y2_output_mae: 2.7893 - val_loss: 19.6284 - val_y1_output_loss: 8.3373 - val_y1_output_mae: 2.3339 - val_y2_output_loss: 11.6247 - val_y2_output_mae: 2.4643
# Epoch 118/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 27.5788 - y1_output_loss: 11.8498 - y1_output_mae: 2.5995 - y2_output_loss: 15.3087 - y2_output_mae: 2.8955 - val_loss: 11.6840 - val_y1_output_loss: 4.6323 - val_y1_output_mae: 1.6542 - val_y2_output_loss: 7.1287 - val_y2_output_mae: 1.8257
# Epoch 119/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.1899 - y1_output_loss: 13.4464 - y1_output_mae: 2.6452 - y2_output_loss: 13.7700 - y2_output_mae: 2.8133 - val_loss: 12.4723 - val_y1_output_loss: 4.9361 - val_y1_output_mae: 1.7409 - val_y2_output_loss: 7.6517 - val_y2_output_mae: 1.8815
# Epoch 120/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.1859 - y1_output_loss: 12.1662 - y1_output_mae: 2.5580 - y2_output_loss: 13.8500 - y2_output_mae: 2.7518 - val_loss: 15.7461 - val_y1_output_loss: 6.0884 - val_y1_output_mae: 1.9837 - val_y2_output_loss: 9.8814 - val_y2_output_mae: 2.2257
# Epoch 121/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.3127 - y1_output_loss: 12.3879 - y1_output_mae: 2.5395 - y2_output_loss: 13.7915 - y2_output_mae: 2.7970 - val_loss: 11.4658 - val_y1_output_loss: 4.8966 - val_y1_output_mae: 1.7680 - val_y2_output_loss: 6.6689 - val_y2_output_mae: 1.7351
# Epoch 122/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.6277 - y1_output_loss: 13.1660 - y1_output_mae: 2.6370 - y2_output_loss: 13.0211 - y2_output_mae: 2.7528 - val_loss: 11.1217 - val_y1_output_loss: 4.4112 - val_y1_output_mae: 1.6122 - val_y2_output_loss: 6.7691 - val_y2_output_mae: 1.7499
# Epoch 123/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.8384 - y1_output_loss: 12.3734 - y1_output_mae: 2.4971 - y2_output_loss: 13.1562 - y2_output_mae: 2.6906 - val_loss: 13.1693 - val_y1_output_loss: 4.7463 - val_y1_output_mae: 1.7010 - val_y2_output_loss: 8.5446 - val_y2_output_mae: 2.0179
# Epoch 124/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.7342 - y1_output_loss: 12.6209 - y1_output_mae: 2.5889 - y2_output_loss: 14.3880 - y2_output_mae: 2.8220 - val_loss: 18.2235 - val_y1_output_loss: 7.8490 - val_y1_output_mae: 2.2480 - val_y2_output_loss: 10.6231 - val_y2_output_mae: 2.3328
# Epoch 125/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.5852 - y1_output_loss: 15.2949 - y1_output_mae: 2.6436 - y2_output_loss: 16.2267 - y2_output_mae: 2.8285 - val_loss: 17.5989 - val_y1_output_loss: 6.1949 - val_y1_output_mae: 1.9938 - val_y2_output_loss: 11.6484 - val_y2_output_mae: 2.4727
# Epoch 126/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.1255 - y1_output_loss: 13.2894 - y1_output_mae: 2.6114 - y2_output_loss: 13.4079 - y2_output_mae: 2.6397 - val_loss: 13.0350 - val_y1_output_loss: 5.6986 - val_y1_output_mae: 1.8596 - val_y2_output_loss: 7.5500 - val_y2_output_mae: 1.9094
# Epoch 127/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.9240 - y1_output_loss: 12.6852 - y1_output_mae: 2.5487 - y2_output_loss: 11.8556 - y2_output_mae: 2.6290 - val_loss: 15.8357 - val_y1_output_loss: 7.4597 - val_y1_output_mae: 2.1445 - val_y2_output_loss: 8.6434 - val_y2_output_mae: 2.0547
# Epoch 128/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.7143 - y1_output_loss: 10.3066 - y1_output_mae: 2.4407 - y2_output_loss: 13.8584 - y2_output_mae: 2.7763 - val_loss: 14.7497 - val_y1_output_loss: 5.7470 - val_y1_output_mae: 1.8991 - val_y2_output_loss: 9.2542 - val_y2_output_mae: 2.1290
# Epoch 129/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.9915 - y1_output_loss: 13.5484 - y1_output_mae: 2.6073 - y2_output_loss: 13.1606 - y2_output_mae: 2.7013 - val_loss: 14.5406 - val_y1_output_loss: 6.7533 - val_y1_output_mae: 2.0523 - val_y2_output_loss: 8.0226 - val_y2_output_mae: 1.9393
# Epoch 130/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.0347 - y1_output_loss: 11.5203 - y1_output_mae: 2.5703 - y2_output_loss: 14.2898 - y2_output_mae: 2.8509 - val_loss: 13.4571 - val_y1_output_loss: 4.8547 - val_y1_output_mae: 1.7395 - val_y2_output_loss: 8.8476 - val_y2_output_mae: 2.0958
# Epoch 131/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.6181 - y1_output_loss: 12.2269 - y1_output_mae: 2.5098 - y2_output_loss: 13.6560 - y2_output_mae: 2.7329 - val_loss: 12.0736 - val_y1_output_loss: 4.7675 - val_y1_output_mae: 1.7489 - val_y2_output_loss: 7.4606 - val_y2_output_mae: 1.9316
# Epoch 132/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.8342 - y1_output_loss: 10.8266 - y1_output_mae: 2.4145 - y2_output_loss: 12.8525 - y2_output_mae: 2.6678 - val_loss: 14.3147 - val_y1_output_loss: 6.2679 - val_y1_output_mae: 2.0172 - val_y2_output_loss: 8.2612 - val_y2_output_mae: 2.0667
# Epoch 133/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.2413 - y1_output_loss: 10.9932 - y1_output_mae: 2.4657 - y2_output_loss: 11.9375 - y2_output_mae: 2.5858 - val_loss: 12.4869 - val_y1_output_loss: 5.8971 - val_y1_output_mae: 1.9293 - val_y2_output_loss: 6.7574 - val_y2_output_mae: 1.7886
# Epoch 134/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.2370 - y1_output_loss: 12.0222 - y1_output_mae: 2.5016 - y2_output_loss: 12.4244 - y2_output_mae: 2.6261 - val_loss: 16.0323 - val_y1_output_loss: 7.5299 - val_y1_output_mae: 2.1524 - val_y2_output_loss: 8.7552 - val_y2_output_mae: 2.0751
# Epoch 135/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.0865 - y1_output_loss: 11.8213 - y1_output_mae: 2.4838 - y2_output_loss: 13.0914 - y2_output_mae: 2.6192 - val_loss: 11.4348 - val_y1_output_loss: 4.5136 - val_y1_output_mae: 1.6947 - val_y2_output_loss: 7.0567 - val_y2_output_mae: 1.8238
# Epoch 136/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.0320 - y1_output_loss: 10.6502 - y1_output_mae: 2.4029 - y2_output_loss: 12.8630 - y2_output_mae: 2.7061 - val_loss: 10.0941 - val_y1_output_loss: 3.8182 - val_y1_output_mae: 1.5201 - val_y2_output_loss: 6.3280 - val_y2_output_mae: 1.7646
# Epoch 137/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.3803 - y1_output_loss: 12.1611 - y1_output_mae: 2.5554 - y2_output_loss: 14.5621 - y2_output_mae: 2.8249 - val_loss: 14.2473 - val_y1_output_loss: 5.4661 - val_y1_output_mae: 1.8349 - val_y2_output_loss: 8.9887 - val_y2_output_mae: 2.0797
# Epoch 138/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.3350 - y1_output_loss: 10.7751 - y1_output_mae: 2.3411 - y2_output_loss: 13.7527 - y2_output_mae: 2.7407 - val_loss: 14.2102 - val_y1_output_loss: 6.0342 - val_y1_output_mae: 1.9439 - val_y2_output_loss: 8.3749 - val_y2_output_mae: 2.0485
# Epoch 139/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.0734 - y1_output_loss: 10.1743 - y1_output_mae: 2.3158 - y2_output_loss: 13.3197 - y2_output_mae: 2.7302 - val_loss: 15.7288 - val_y1_output_loss: 5.5493 - val_y1_output_mae: 1.8430 - val_y2_output_loss: 10.4640 - val_y2_output_mae: 2.2792
# Epoch 140/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 24.3323 - y1_output_loss: 10.9587 - y1_output_mae: 2.3980 - y2_output_loss: 13.0964 - y2_output_mae: 2.6682 - val_loss: 13.9830 - val_y1_output_loss: 6.6428 - val_y1_output_mae: 2.0221 - val_y2_output_loss: 7.5854 - val_y2_output_mae: 1.9385
# Epoch 141/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.4973 - y1_output_loss: 11.0678 - y1_output_mae: 2.4242 - y2_output_loss: 12.1419 - y2_output_mae: 2.6310 - val_loss: 16.0259 - val_y1_output_loss: 5.7326 - val_y1_output_mae: 1.9113 - val_y2_output_loss: 10.6051 - val_y2_output_mae: 2.3652
# Epoch 142/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.6115 - y1_output_loss: 10.9649 - y1_output_mae: 2.4221 - y2_output_loss: 12.1609 - y2_output_mae: 2.6059 - val_loss: 16.7197 - val_y1_output_loss: 7.9643 - val_y1_output_mae: 2.2417 - val_y2_output_loss: 9.0399 - val_y2_output_mae: 2.1729
# Epoch 143/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.1722 - y1_output_loss: 9.9509 - y1_output_mae: 2.3344 - y2_output_loss: 10.9293 - y2_output_mae: 2.4799 - val_loss: 10.7091 - val_y1_output_loss: 4.4297 - val_y1_output_mae: 1.6733 - val_y2_output_loss: 6.3440 - val_y2_output_mae: 1.7897
# Epoch 144/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.8775 - y1_output_loss: 9.8454 - y1_output_mae: 2.2707 - y2_output_loss: 12.0427 - y2_output_mae: 2.6173 - val_loss: 9.8763 - val_y1_output_loss: 3.6483 - val_y1_output_mae: 1.4618 - val_y2_output_loss: 6.2683 - val_y2_output_mae: 1.7493
# Epoch 145/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.7303 - y1_output_loss: 10.2699 - y1_output_mae: 2.3630 - y2_output_loss: 12.0772 - y2_output_mae: 2.5836 - val_loss: 12.7907 - val_y1_output_loss: 5.5069 - val_y1_output_mae: 1.8893 - val_y2_output_loss: 7.4759 - val_y2_output_mae: 1.9299
# Epoch 146/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.8682 - y1_output_loss: 10.9944 - y1_output_mae: 2.4060 - y2_output_loss: 11.9557 - y2_output_mae: 2.5682 - val_loss: 11.1856 - val_y1_output_loss: 4.9863 - val_y1_output_mae: 1.7896 - val_y2_output_loss: 6.3576 - val_y2_output_mae: 1.7764
# Epoch 147/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.0085 - y1_output_loss: 10.8009 - y1_output_mae: 2.2998 - y2_output_loss: 12.5134 - y2_output_mae: 2.6096 - val_loss: 14.7764 - val_y1_output_loss: 5.1217 - val_y1_output_mae: 1.8121 - val_y2_output_loss: 9.9191 - val_y2_output_mae: 2.2868
# Epoch 148/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.4453 - y1_output_loss: 8.9126 - y1_output_mae: 2.1592 - y2_output_loss: 11.0309 - y2_output_mae: 2.4577 - val_loss: 13.6579 - val_y1_output_loss: 6.5137 - val_y1_output_mae: 2.0344 - val_y2_output_loss: 7.3694 - val_y2_output_mae: 1.9337
# Epoch 149/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.1771 - y1_output_loss: 8.9279 - y1_output_mae: 2.2232 - y2_output_loss: 12.3410 - y2_output_mae: 2.5290 - val_loss: 10.3652 - val_y1_output_loss: 4.1274 - val_y1_output_mae: 1.6226 - val_y2_output_loss: 6.3635 - val_y2_output_mae: 1.8170
# Epoch 150/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.4637 - y1_output_loss: 9.5020 - y1_output_mae: 2.2118 - y2_output_loss: 11.6342 - y2_output_mae: 2.5695 - val_loss: 12.1616 - val_y1_output_loss: 4.5841 - val_y1_output_mae: 1.7113 - val_y2_output_loss: 7.7984 - val_y2_output_mae: 2.0082
# Epoch 151/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.9762 - y1_output_loss: 9.1568 - y1_output_mae: 2.2561 - y2_output_loss: 13.0917 - y2_output_mae: 2.6143 - val_loss: 15.6395 - val_y1_output_loss: 7.0705 - val_y1_output_mae: 2.0746 - val_y2_output_loss: 8.8629 - val_y2_output_mae: 2.1215
# Epoch 152/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.5736 - y1_output_loss: 8.9091 - y1_output_mae: 2.1649 - y2_output_loss: 11.4890 - y2_output_mae: 2.5564 - val_loss: 14.3991 - val_y1_output_loss: 6.8538 - val_y1_output_mae: 2.0486 - val_y2_output_loss: 7.7777 - val_y2_output_mae: 1.9824
# Epoch 153/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.8506 - y1_output_loss: 10.2028 - y1_output_mae: 2.3327 - y2_output_loss: 12.3189 - y2_output_mae: 2.5995 - val_loss: 14.3822 - val_y1_output_loss: 5.6891 - val_y1_output_mae: 1.8833 - val_y2_output_loss: 8.9634 - val_y2_output_mae: 2.1536
# Epoch 154/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.5302 - y1_output_loss: 10.2588 - y1_output_mae: 2.3378 - y2_output_loss: 11.7559 - y2_output_mae: 2.5680 - val_loss: 11.6018 - val_y1_output_loss: 4.8688 - val_y1_output_mae: 1.7592 - val_y2_output_loss: 6.9006 - val_y2_output_mae: 1.8780
# Epoch 155/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.9262 - y1_output_loss: 9.6947 - y1_output_mae: 2.2148 - y2_output_loss: 10.6592 - y2_output_mae: 2.4855 - val_loss: 11.5803 - val_y1_output_loss: 4.7885 - val_y1_output_mae: 1.7466 - val_y2_output_loss: 6.9515 - val_y2_output_mae: 1.8588
# Epoch 156/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.8072 - y1_output_loss: 10.0885 - y1_output_mae: 2.3416 - y2_output_loss: 12.2819 - y2_output_mae: 2.5659 - val_loss: 9.2712 - val_y1_output_loss: 3.4077 - val_y1_output_mae: 1.4554 - val_y2_output_loss: 5.9670 - val_y2_output_mae: 1.7222
# Epoch 157/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.7031 - y1_output_loss: 9.0070 - y1_output_mae: 2.2171 - y2_output_loss: 11.6606 - y2_output_mae: 2.5023 - val_loss: 12.7616 - val_y1_output_loss: 7.0165 - val_y1_output_mae: 2.0447 - val_y2_output_loss: 5.9956 - val_y2_output_mae: 1.7430
# Epoch 158/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.8839 - y1_output_loss: 9.4784 - y1_output_mae: 2.1594 - y2_output_loss: 12.7219 - y2_output_mae: 2.6045 - val_loss: 10.8448 - val_y1_output_loss: 4.9106 - val_y1_output_mae: 1.7508 - val_y2_output_loss: 6.1180 - val_y2_output_mae: 1.7492
# Epoch 159/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.9489 - y1_output_loss: 9.7385 - y1_output_mae: 2.2576 - y2_output_loss: 11.2461 - y2_output_mae: 2.4563 - val_loss: 8.0574 - val_y1_output_loss: 3.1276 - val_y1_output_mae: 1.3923 - val_y2_output_loss: 4.9683 - val_y2_output_mae: 1.6982
# Epoch 160/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.6684 - y1_output_loss: 9.7080 - y1_output_mae: 2.2996 - y2_output_loss: 11.4700 - y2_output_mae: 2.5903 - val_loss: 8.7440 - val_y1_output_loss: 3.0451 - val_y1_output_mae: 1.3932 - val_y2_output_loss: 5.7921 - val_y2_output_mae: 1.7820
# Epoch 161/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.3613 - y1_output_loss: 9.3497 - y1_output_mae: 2.2246 - y2_output_loss: 10.3014 - y2_output_mae: 2.4973 - val_loss: 10.1379 - val_y1_output_loss: 4.6338 - val_y1_output_mae: 1.7102 - val_y2_output_loss: 5.6716 - val_y2_output_mae: 1.7188
# Epoch 162/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.3015 - y1_output_loss: 9.4192 - y1_output_mae: 2.2511 - y2_output_loss: 10.4682 - y2_output_mae: 2.4460 - val_loss: 10.9665 - val_y1_output_loss: 4.4824 - val_y1_output_mae: 1.6892 - val_y2_output_loss: 6.6647 - val_y2_output_mae: 1.8320
# Epoch 163/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.1704 - y1_output_loss: 8.6785 - y1_output_mae: 2.1110 - y2_output_loss: 10.7461 - y2_output_mae: 2.4324 - val_loss: 8.9192 - val_y1_output_loss: 3.6958 - val_y1_output_mae: 1.5246 - val_y2_output_loss: 5.3587 - val_y2_output_mae: 1.7022
# Epoch 164/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.5130 - y1_output_loss: 10.0051 - y1_output_mae: 2.2430 - y2_output_loss: 11.6950 - y2_output_mae: 2.5818 - val_loss: 11.2296 - val_y1_output_loss: 4.9307 - val_y1_output_mae: 1.7488 - val_y2_output_loss: 6.5066 - val_y2_output_mae: 1.8068
# Epoch 165/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.7940 - y1_output_loss: 9.8474 - y1_output_mae: 2.2207 - y2_output_loss: 12.2809 - y2_output_mae: 2.4555 - val_loss: 8.7527 - val_y1_output_loss: 3.9354 - val_y1_output_mae: 1.5771 - val_y2_output_loss: 4.9211 - val_y2_output_mae: 1.6652
# Epoch 166/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.9992 - y1_output_loss: 9.0772 - y1_output_mae: 2.2038 - y2_output_loss: 10.1410 - y2_output_mae: 2.3750 - val_loss: 9.5812 - val_y1_output_loss: 3.5404 - val_y1_output_mae: 1.4988 - val_y2_output_loss: 6.1736 - val_y2_output_mae: 1.8429
# Epoch 167/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.8401 - y1_output_loss: 8.4293 - y1_output_mae: 2.1460 - y2_output_loss: 11.4194 - y2_output_mae: 2.5004 - val_loss: 14.0882 - val_y1_output_loss: 6.9144 - val_y1_output_mae: 2.0425 - val_y2_output_loss: 7.4266 - val_y2_output_mae: 2.0019
# Epoch 168/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.6249 - y1_output_loss: 8.7299 - y1_output_mae: 2.0853 - y2_output_loss: 12.2018 - y2_output_mae: 2.5797 - val_loss: 16.6645 - val_y1_output_loss: 8.4224 - val_y1_output_mae: 2.2031 - val_y2_output_loss: 8.5763 - val_y2_output_mae: 2.1191
# Epoch 169/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.1285 - y1_output_loss: 8.3098 - y1_output_mae: 2.0757 - y2_output_loss: 9.9897 - y2_output_mae: 2.3239 - val_loss: 11.9598 - val_y1_output_loss: 4.6653 - val_y1_output_mae: 1.6938 - val_y2_output_loss: 7.5664 - val_y2_output_mae: 1.9805
# Epoch 170/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.4610 - y1_output_loss: 9.3858 - y1_output_mae: 2.1947 - y2_output_loss: 11.0911 - y2_output_mae: 2.4825 - val_loss: 15.1274 - val_y1_output_loss: 8.9001 - val_y1_output_mae: 2.2525 - val_y2_output_loss: 6.5283 - val_y2_output_mae: 1.8323
# Epoch 171/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.7947 - y1_output_loss: 9.8181 - y1_output_mae: 2.2426 - y2_output_loss: 11.2807 - y2_output_mae: 2.4738 - val_loss: 9.0922 - val_y1_output_loss: 3.5206 - val_y1_output_mae: 1.4816 - val_y2_output_loss: 5.7109 - val_y2_output_mae: 1.7350
# Epoch 172/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.3338 - y1_output_loss: 8.8765 - y1_output_mae: 2.1699 - y2_output_loss: 12.7069 - y2_output_mae: 2.6161 - val_loss: 11.9329 - val_y1_output_loss: 5.8225 - val_y1_output_mae: 1.8665 - val_y2_output_loss: 6.3641 - val_y2_output_mae: 1.8335
# Epoch 173/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.5371 - y1_output_loss: 7.1011 - y1_output_mae: 1.9944 - y2_output_loss: 11.0337 - y2_output_mae: 2.4899 - val_loss: 11.6702 - val_y1_output_loss: 5.7240 - val_y1_output_mae: 1.8721 - val_y2_output_loss: 6.1758 - val_y2_output_mae: 1.7882
# Epoch 174/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.4518 - y1_output_loss: 8.8200 - y1_output_mae: 2.1227 - y2_output_loss: 10.4357 - y2_output_mae: 2.3747 - val_loss: 12.0677 - val_y1_output_loss: 6.1726 - val_y1_output_mae: 1.9327 - val_y2_output_loss: 6.1472 - val_y2_output_mae: 1.8459
# Epoch 175/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.3736 - y1_output_loss: 8.5656 - y1_output_mae: 2.1355 - y2_output_loss: 10.6983 - y2_output_mae: 2.3926 - val_loss: 11.4827 - val_y1_output_loss: 4.9455 - val_y1_output_mae: 1.7350 - val_y2_output_loss: 6.7974 - val_y2_output_mae: 1.8784
# Epoch 176/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.5977 - y1_output_loss: 8.9372 - y1_output_mae: 2.1419 - y2_output_loss: 10.7854 - y2_output_mae: 2.2829 - val_loss: 11.3694 - val_y1_output_loss: 5.0313 - val_y1_output_mae: 1.7335 - val_y2_output_loss: 6.5889 - val_y2_output_mae: 1.8516
# Epoch 177/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.5953 - y1_output_loss: 8.1145 - y1_output_mae: 2.0544 - y2_output_loss: 10.0971 - y2_output_mae: 2.3795 - val_loss: 11.9744 - val_y1_output_loss: 5.2334 - val_y1_output_mae: 1.8349 - val_y2_output_loss: 6.9716 - val_y2_output_mae: 1.9523
# Epoch 178/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.4832 - y1_output_loss: 8.0361 - y1_output_mae: 2.0257 - y2_output_loss: 10.5940 - y2_output_mae: 2.3588 - val_loss: 10.8550 - val_y1_output_loss: 5.3718 - val_y1_output_mae: 1.8153 - val_y2_output_loss: 5.7281 - val_y2_output_mae: 1.7363
# Epoch 179/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 18.6813 - y1_output_loss: 8.0849 - y1_output_mae: 2.0928 - y2_output_loss: 10.1274 - y2_output_mae: 2.3122 - val_loss: 10.8987 - val_y1_output_loss: 5.1254 - val_y1_output_mae: 1.7576 - val_y2_output_loss: 6.0143 - val_y2_output_mae: 1.8061
# Epoch 180/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.7961 - y1_output_loss: 7.1241 - y1_output_mae: 1.9589 - y2_output_loss: 9.5473 - y2_output_mae: 2.2863 - val_loss: 11.3358 - val_y1_output_loss: 5.5520 - val_y1_output_mae: 1.8535 - val_y2_output_loss: 6.0064 - val_y2_output_mae: 1.8087
# Epoch 181/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.8716 - y1_output_loss: 7.2201 - y1_output_mae: 1.9569 - y2_output_loss: 10.5048 - y2_output_mae: 2.4120 - val_loss: 7.3431 - val_y1_output_loss: 2.9084 - val_y1_output_mae: 1.3975 - val_y2_output_loss: 4.4813 - val_y2_output_mae: 1.6824
# Epoch 182/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.9699 - y1_output_loss: 8.0828 - y1_output_mae: 2.0460 - y2_output_loss: 10.4586 - y2_output_mae: 2.4101 - val_loss: 8.2696 - val_y1_output_loss: 3.6544 - val_y1_output_mae: 1.4772 - val_y2_output_loss: 4.7347 - val_y2_output_mae: 1.6120
# Epoch 183/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.5310 - y1_output_loss: 7.4776 - y1_output_mae: 1.9792 - y2_output_loss: 10.7910 - y2_output_mae: 2.3451 - val_loss: 9.3564 - val_y1_output_loss: 4.3628 - val_y1_output_mae: 1.6516 - val_y2_output_loss: 5.1433 - val_y2_output_mae: 1.6876
# Epoch 184/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.7939 - y1_output_loss: 8.0472 - y1_output_mae: 2.1069 - y2_output_loss: 10.3193 - y2_output_mae: 2.4021 - val_loss: 9.0624 - val_y1_output_loss: 4.6262 - val_y1_output_mae: 1.6552 - val_y2_output_loss: 4.5950 - val_y2_output_mae: 1.6019
# Epoch 185/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.5503 - y1_output_loss: 7.6403 - y1_output_mae: 2.0011 - y2_output_loss: 9.4473 - y2_output_mae: 2.2955 - val_loss: 8.1192 - val_y1_output_loss: 3.3607 - val_y1_output_mae: 1.4256 - val_y2_output_loss: 4.8699 - val_y2_output_mae: 1.5533
# Epoch 186/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.1518 - y1_output_loss: 7.3461 - y1_output_mae: 1.9150 - y2_output_loss: 8.9253 - y2_output_mae: 2.2376 - val_loss: 7.6585 - val_y1_output_loss: 2.9180 - val_y1_output_mae: 1.3510 - val_y2_output_loss: 4.8581 - val_y2_output_mae: 1.5847
# Epoch 187/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.2479 - y1_output_loss: 8.1710 - y1_output_mae: 2.1026 - y2_output_loss: 9.8644 - y2_output_mae: 2.2850 - val_loss: 7.4789 - val_y1_output_loss: 3.3200 - val_y1_output_mae: 1.4522 - val_y2_output_loss: 4.2026 - val_y2_output_mae: 1.5486
# Epoch 188/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.5685 - y1_output_loss: 7.2289 - y1_output_mae: 1.8870 - y2_output_loss: 8.4386 - y2_output_mae: 2.1173 - val_loss: 8.9694 - val_y1_output_loss: 3.9585 - val_y1_output_mae: 1.5966 - val_y2_output_loss: 5.1681 - val_y2_output_mae: 1.6775
# Epoch 189/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.4513 - y1_output_loss: 8.3500 - y1_output_mae: 2.0206 - y2_output_loss: 8.4608 - y2_output_mae: 2.1682 - val_loss: 7.5929 - val_y1_output_loss: 3.3394 - val_y1_output_mae: 1.4527 - val_y2_output_loss: 4.3470 - val_y2_output_mae: 1.5706
# Epoch 190/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.7299 - y1_output_loss: 7.4239 - y1_output_mae: 1.9478 - y2_output_loss: 10.7411 - y2_output_mae: 2.3106 - val_loss: 9.4259 - val_y1_output_loss: 4.9868 - val_y1_output_mae: 1.7380 - val_y2_output_loss: 4.6157 - val_y2_output_mae: 1.5642
# Epoch 191/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.2609 - y1_output_loss: 7.6085 - y1_output_mae: 2.0484 - y2_output_loss: 9.2883 - y2_output_mae: 2.2587 - val_loss: 9.4061 - val_y1_output_loss: 4.6418 - val_y1_output_mae: 1.6698 - val_y2_output_loss: 4.9301 - val_y2_output_mae: 1.5860
# Epoch 192/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.8112 - y1_output_loss: 8.7393 - y1_output_mae: 2.1440 - y2_output_loss: 9.7573 - y2_output_mae: 2.3199 - val_loss: 10.0906 - val_y1_output_loss: 5.0833 - val_y1_output_mae: 1.7137 - val_y2_output_loss: 5.2180 - val_y2_output_mae: 1.6078
# Epoch 193/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.6978 - y1_output_loss: 7.6318 - y1_output_mae: 2.0390 - y2_output_loss: 10.0098 - y2_output_mae: 2.2738 - val_loss: 9.7149 - val_y1_output_loss: 3.7311 - val_y1_output_mae: 1.4963 - val_y2_output_loss: 6.1641 - val_y2_output_mae: 1.7336
# Epoch 194/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.8759 - y1_output_loss: 7.3295 - y1_output_mae: 1.9939 - y2_output_loss: 10.0086 - y2_output_mae: 2.2485 - val_loss: 13.3311 - val_y1_output_loss: 7.5503 - val_y1_output_mae: 2.1447 - val_y2_output_loss: 5.9952 - val_y2_output_mae: 1.7685
# Epoch 195/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.6823 - y1_output_loss: 7.7416 - y1_output_mae: 1.9848 - y2_output_loss: 9.1983 - y2_output_mae: 2.2550 - val_loss: 15.3106 - val_y1_output_loss: 7.7234 - val_y1_output_mae: 2.1344 - val_y2_output_loss: 7.8825 - val_y2_output_mae: 2.0050
# Epoch 196/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.9152 - y1_output_loss: 7.3344 - y1_output_mae: 1.9401 - y2_output_loss: 9.2494 - y2_output_mae: 2.2190 - val_loss: 16.3380 - val_y1_output_loss: 8.0074 - val_y1_output_mae: 2.1315 - val_y2_output_loss: 8.6340 - val_y2_output_mae: 2.0676
# Epoch 197/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 17.1486 - y1_output_loss: 6.8403 - y1_output_mae: 1.9168 - y2_output_loss: 10.0158 - y2_output_mae: 2.3127 - val_loss: 13.7536 - val_y1_output_loss: 7.4077 - val_y1_output_mae: 2.1093 - val_y2_output_loss: 6.6595 - val_y2_output_mae: 1.8226
# Epoch 198/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.1624 - y1_output_loss: 7.0217 - y1_output_mae: 1.8827 - y2_output_loss: 9.4167 - y2_output_mae: 2.2301 - val_loss: 8.7754 - val_y1_output_loss: 4.3693 - val_y1_output_mae: 1.6040 - val_y2_output_loss: 4.5960 - val_y2_output_mae: 1.5014
# Epoch 199/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.4000 - y1_output_loss: 7.0451 - y1_output_mae: 1.9058 - y2_output_loss: 8.4250 - y2_output_mae: 2.0620 - val_loss: 6.9478 - val_y1_output_loss: 2.7349 - val_y1_output_mae: 1.2715 - val_y2_output_loss: 4.3707 - val_y2_output_mae: 1.4685
# Epoch 200/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.1512 - y1_output_loss: 7.0606 - y1_output_mae: 1.9112 - y2_output_loss: 8.7723 - y2_output_mae: 2.2262 - val_loss: 9.1453 - val_y1_output_loss: 4.9373 - val_y1_output_mae: 1.7215 - val_y2_output_loss: 4.4144 - val_y2_output_mae: 1.5118

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'val_loss', 'val_y1_output_loss', 'val_y1_output_mae', 'val_y2_output_loss', 'val_y2_output_mae', 'y1_output_loss', 'y1_output_mae', 'y2_output_loss', 'y2_output_mae'])

# %%
# Evaluamos el modelo
results = model.evaluate(X_test, [y1_test, y2_test], verbose=0)

test_loss, y1_loss, y2_loss, test_mae_heating, test_mae_cooling = results

print(f"Total Test Loss: {test_loss:.4f}")
print(f"Heating Loss: {y1_loss:.4f}, Cooling Loss: {y2_loss:.4f}")
print(f"Test MAE for Heating Load: {test_mae_heating:.4f} Wh")
print(f"Test MAE for Cooling Load: {test_mae_cooling:.4f} Wh")
# Out:
# Total Test Loss: 9.1453
# Heating Loss: 4.9373, Cooling Loss: 4.4144
# Test MAE for Heating Load: 1.7215 Wh
# Test MAE for Cooling Load: 1.5118 Wh

# %%
import matplotlib.pyplot as plt


print(history.history.keys())

# ---- Graficamos el loss, que en este caso decidimos que fuera el MSE
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Total Training Loss')
plt.plot(history.history['val_loss'], label='Total Validation Loss')
plt.plot(history.history['y1_output_loss'], label='Heating Training Loss')
plt.plot(history.history['val_y1_output_loss'], label='Heating Validation Loss')
plt.plot(history.history['y2_output_loss'], label='Cooling Training Loss')
plt.plot(history.history['val_y2_output_loss'], label='Cooling Validation Loss')
plt.title('Model Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# Graficamos el MAE
plt.figure(figsize=(10, 6))
plt.plot(history.history['y1_output_mae'], label='Heating Training MAE')
plt.plot(history.history['val_y1_output_mae'], label='Heating Validation MAE')
plt.plot(history.history['y2_output_mae'], label='Cooling Training MAE')
plt.plot(history.history['val_y2_output_mae'], label='Cooling Validation MAE')
plt.title('Model MAE over Epochs')
plt.xlabel('Epochs')
plt.ylabel('MAE (Wh)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# dict_keys(['loss', 'val_loss', 'val_y1_output_loss', 'val_y1_output_mae', 'val_y2_output_loss', 'val_y2_output_mae', 'y1_output_loss', 'y1_output_mae', 'y2_output_loss', 'y2_output_mae'])

# %%
# Realizar predicciones
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

#Como tenemos dos targets, las predicciones hay que separarlas
y_train_pred_heating = y_pred_train[0].flatten()
y_train_pred_cooling = y_pred_train[1].flatten()

y_test_pred_heating = y_pred_test[0].flatten()
y_test_pred_cooling = y_pred_test[1].flatten()
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
#Metricas de performance para heating

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import r2_score

def regression_metrics(y_true, y_pred):
    r2 = r2_score(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(root_mean_squared_error(y_true, y_pred))
    return r2, mae, rmse

# Metricas train
r2_train_heat, mae_train_heat, rmse_train_heat = regression_metrics(y1_train, y_train_pred_heating)
r2_train_cool, mae_train_cool, rmse_train_cool = regression_metrics(y2_train, y_train_pred_cooling)
print("=== Train Performance ===")
print(f"Heating Load: R²={r2_train_heat:.3f}, MAE={mae_train_heat:.3f}, RMSE={rmse_train_heat:.3f}")
print(f"Cooling Load: R²={r2_train_cool:.3f}, MAE={mae_train_cool:.3f}, RMSE={rmse_train_cool:.3f}")

# metricas test
r2_test_heat, mae_test_heat, rmse_test_heat = regression_metrics(y1_test, y_test_pred_heating)
r2_test_cool, mae_test_cool, rmse_test_cool = regression_metrics(y2_test, y_test_pred_cooling)
print("\n=== Test Performance ===")
print(f"Heating Load: R²={r2_test_heat:.3f}, MAE={mae_test_heat:.3f}, RMSE={rmse_test_heat:.3f}")
print(f"Cooling Load: R²={r2_test_cool:.3f}, MAE={mae_test_cool:.3f}, RMSE={rmse_test_cool:.3f}")
# Out:
# === Train Performance ===
# Heating Load: R²=0.959, MAE=1.536, RMSE=1.428
# Cooling Load: R²=0.961, MAE=1.329, RMSE=1.371
#
# === Test Performance ===
# Heating Load: R²=0.954, MAE=1.721, RMSE=1.483
# Cooling Load: R²=0.954, MAE=1.512, RMSE=1.440

# %% [markdown]
# #### Cross Validation

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import tensorflow as tf
from tensorflow.keras import layers, models

def build_model(input_dim):
    input_layer = layers.Input(shape=(input_dim,))
    
    # Capas compartidas
    x = layers.Dense(128, activation='relu')(input_layer)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    
    # Heating
    h = layers.Dense(64, activation='relu')(x)
    h = layers.Dropout(0.2)(h)
    h = layers.Dense(32, activation='relu')(h)
    y1 = layers.Dense(1, name='heating_output')(h)
    
    # Cooling
    c = layers.Dense(64, activation='relu')(x)
    c = layers.Dropout(0.2)(c)
    c = layers.Dense(32, activation='relu')(c)
    y2 = layers.Dense(1, name='cooling_output')(c)
    
    model = models.Model(inputs=input_layer, outputs=[y1, y2])
    model.compile(optimizer='adam', loss='mse')
    return model

# %%
from sklearn.model_selection import KFold

from sklearn.preprocessing import StandardScaler
from numpy import sqrt

#KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)

r2_heat, r2_cool = [], []
mae_heat, mae_cool = [], []
rmse_heat, rmse_cool = [], []

for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
    print(f"\n Fold {fold+1}")
    
    # Split data
    X_train, X_val = X[train_idx], X[val_idx]
    y_train_heat, y_val_heat = df['Y1'][train_idx], df['Y1'][val_idx]
    y_train_cool, y_val_cool = df['Y2'][train_idx], df['Y2'][val_idx]
    
    # Scale inputs
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)
    
    # Build & train model
    model = build_model(X.shape[1])
    model.fit(
        X_train, [y_train_heat, y_train_cool],
        epochs=80, batch_size=32, verbose=0
    )
    
    # Predict
    y_pred_heat, y_pred_cool = model.predict(X_val, verbose=0)
    
    # Flatten
    y_pred_heat, y_pred_cool = y_pred_heat.flatten(), y_pred_cool.flatten()
    
    # Compute metrics
    r2_heat.append(r2_score(y_val_heat, y_pred_heat))
    r2_cool.append(r2_score(y_val_cool, y_pred_cool))
    mae_heat.append(mean_absolute_error(y_val_heat, y_pred_heat))
    mae_cool.append(mean_absolute_error(y_val_cool, y_pred_cool))
    rmse_heat.append(sqrt(mean_squared_error(y_val_heat, y_pred_heat)))
    rmse_cool.append(sqrt(mean_squared_error(y_val_cool, y_pred_cool)))
# Out:
#  Fold 1
#
#  Fold 2
# WARNING:tensorflow:5 out of the last 16 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x33f8a0ee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
#  Fold 3
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x340efe830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
#  Fold 4
#
#  Fold 5

# %%
print("\n=== Cross-Validation Results ===")
print(f"Heating Load: R2={np.mean(r2_heat):.3f}±{np.std(r2_heat):.3f}, "
      f"MAE={np.mean(mae_heat):.3f}, RMSE={np.mean(rmse_heat):.3f}")
print(f"Cooling Load: R2={np.mean(r2_cool):.3f}±{np.std(r2_cool):.3f}, "
      f"MAE={np.mean(mae_cool):.3f}, RMSE={np.mean(rmse_cool):.3f}")
# Out:
# === Cross-Validation Results ===
# Heating Load: R2=0.955±0.006, MAE=1.548, RMSE=2.115
# Cooling Load: R2=0.928±0.008, MAE=1.831, RMSE=2.545

# %% [markdown]
# ## Tuneo de hiperparametros
#
# Especificamente diseniado para redes neuronales

# %%
# Random Serach
import random
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models, optimizers

df = pd.read_csv("ENB2012_data.csv")
X_full = df[['X1','X2','X3','X4','X5','X6','X7','X8']].values
y1_full = df['Y1'].values
y2_full = df['Y2'].values

scaler = StandardScaler()
X_full = scaler.fit_transform(X_full)


X_train_full, X_test_full, y1_train_full, y1_test_full, y2_train_full, y2_test_full = train_test_split(
    X_full, y1_full, y2_full, test_size=0.2, random_state=42
)


# Definimos el contructor del modelo

def build_random_model(params, input_dim):
    input_layer = layers.Input(shape=(input_dim,))
    
    # compartidas
    x = input_layer
    for i in range(params['n_shared_layers']):
        x = layers.Dense(params['n_shared_units'], activation='relu')(x)
        x = layers.Dropout(params['dropout_rate'])(x)
    
    # Heating 
    h = layers.Dense(params['n_shared_units']//2, activation='relu')(x)
    y1 = layers.Dense(1, name='heating_output')(h)
    
    # Cooling 
    c = layers.Dense(params['n_shared_units']//2, activation='relu')(x)
    y2 = layers.Dense(1, name='cooling_output')(c)
    
    model = models.Model(inputs=input_layer, outputs=[y1, y2])
    
    opt = optimizers.Adam(learning_rate=params['learning_rate'])
    model.compile(
        optimizer=opt,
        loss={'heating_output': 'mse', 'cooling_output': 'mse'},
        metrics={'heating_output': 'mae', 'cooling_output': 'mae'}
    )
    
    return model


# Espacio para el random search

param_distributions = {
    'n_shared_layers': [1, 2, 3],
    'n_shared_units': [32, 64, 128, 256],
    'dropout_rate': [0.0, 0.1, 0.2, 0.3, 0.4],
    'learning_rate': [1e-4, 5e-4, 1e-3, 5e-3],
    'batch_size': [16, 32, 64]
}


n_trials = 5
results = []

print("\n Empezamos Random Search")
for i in range(n_trials):
    params = {k: random.choice(v) for k, v in param_distributions.items()}
    print(f"\nTrial {i+1}/{n_trials} with params: {params}")
    
    X_train_rs, X_val_rs, y1_train_rs, y1_val_rs, y2_train_rs, y2_val_rs = train_test_split(
        X_train_full, y1_train_full, y2_train_full, test_size=0.2, random_state=i
    )
    
    model = build_random_model(params, X_train_rs.shape[1])
    history = model.fit(
        X_train_rs, [y1_train_rs, y2_train_rs],
        validation_data=(X_val_rs, [y1_val_rs, y2_val_rs]),
        epochs=50, batch_size=params['batch_size'], verbose=0
    )
    
    val_loss = np.mean(history.history['val_loss'][-5:])
    results.append((params, val_loss))
    print(f"Validation Loss: {val_loss:.4f}")

# Resultados
results.sort(key=lambda x: x[1])
print("\n Results")
for rank, (params, loss) in enumerate(results, 1):
    print(f"{rank:2d}) Val Loss={loss:.4f} | Params={params}")

best_params, best_loss = results[0]
print("\n Mejor configuracion:")
print(best_params)
print(f"Validation Loss: {best_loss:.4f}")
# Out:
#  Empezamos Random Search
#
# Trial 1/5 with params: {'n_shared_layers': 3, 'n_shared_units': 32, 'dropout_rate': 0.4, 'learning_rate': 0.0001, 'batch_size': 16}
# Validation Loss: 69.5736
#
# Trial 2/5 with params: {'n_shared_layers': 3, 'n_shared_units': 128, 'dropout_rate': 0.4, 'learning_rate': 0.0005, 'batch_size': 16}
# Validation Loss: 35.8294
#
# Trial 3/5 with params: {'n_shared_layers': 3, 'n_shared_units': 128, 'dropout_rate': 0.0, 'learning_rate': 0.0001, 'batch_size': 32}
# Validation Loss: 31.1378
#
# Trial 4/5 with params: {'n_shared_layers': 2, 'n_shared_units': 64, 'dropout_rate': 0.0, 'learning_rate': 0.0001, 'batch_size': 64}
# Validation Loss: 459.8102
#
# Trial 5/5 with params: {'n_shared_layers': 1, 'n_shared_units': 32, 'dropout_rate': 0.1, 'learning_rate': 0.005, 'batch_size': 32}
# Validation Loss: 21.4924
#
#  Results
#  1) Val Loss=21.4924 | Params={'n_shared_layers': 1, 'n_shared_units': 32, 'dropout_rate': 0.1, 'learning_rate': 0.005, 'batch_size': 32}
#  2) Val Loss=31.1378 | Params={'n_shared_layers': 3, 'n_shared_units': 128, 'dropout_rate': 0.0, 'learning_rate': 0.0001, 'batch_size': 32}
#  3) Val Loss=35.8294 | Params={'n_shared_layers': 3, 'n_shared_units': 128, 'dropout_rate': 0.4, 'learning_rate': 0.0005, 'batch_size': 16}
#  4) Val Loss=69.5736 | Params={'n_shared_layers': 3, 'n_shared_units': 32, 'dropout_rate': 0.4, 'learning_rate': 0.0001, 'batch_size': 16}
#  5) Val Loss=459.8102 | Params={'n_shared_layers': 2, 'n_shared_units': 64, 'dropout_rate': 0.0, 'learning_rate': 0.0001, 'batch_size': 64}
#
#  Mejor configuracion:
# {'n_shared_layers': 1, 'n_shared_units': 32, 'dropout_rate': 0.1, 'learning_rate': 0.005, 'batch_size': 32}
# Validation Loss: 21.4924

# %% [markdown]
# #### Algunas referencias
#
# - https://keras.io/guides/sequential_model/
# - https://keras.io/api/layers/activations/
# - https://keras.io/optimizers/
# - https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=spiral&regDataset=reg-gauss&learningRate=0.03&regularizationRate=0.003&noise=20&networkShape=4&seed=0.82538&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=regression&initZero=false&hideText=false
